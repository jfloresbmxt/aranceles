# %% [markdown]
# Necesitamos crear un código que extraiga la información de las tablas del pdf. Intenté utilizar pdfplumber pero me percaté que las tablas están pegadas como imágenes, por lo que considero necesario utilizar un nuevo método. Te comparto el pdf y además un código que había utilizado para descargar información de un pdf que estaba mucho más limpio y tenía sus tablas como tablas a diferencia de este. El archivo también es para que te guíes de la estructura del archivo que quiero recibir. Por el momento la parte de los paneles no es necesaria, simplemente quiero obtener la información en formato excel para tenerla visualizable y usable como base de datos.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/39.0 MB 14.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.2/39.0 MB 11.8 MB/s eta 0:00:03
#    -------- ------------------------------- 8.1/39.0 MB 14.4 MB/s eta 0:00:03
#    ------------ --------------------------- 11.8/39.0 MB 15.2 MB/s eta 0:00:02
#    ------------- -------------------------- 13.4/39.0 MB 15.6 MB/s eta 0:00:02
#    ------------- -------------------------- 13.6/39.0 MB 11.7 MB/s eta 0:00:03
#    -------------- ------------------------- 14.4/39.0 MB 10.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.3/39.0 MB 10.0 MB/s eta 0:00:03
#    -------------------- ------------------- 19.7/39.0 MB 10.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.3/39.0 MB 11.6 MB/s eta 0:00:02
#    ------------------------ --------------- 23.9/39.0 MB 10.6 MB/s eta 0:00:02
#    -------------------------- ------------- 25.7/39.0 MB 10.4 MB/s eta 0:00:02
#    ------------------------------ --------- 29.4/39.0 MB 11.0 MB/s eta 0:00:01
#    --------------------------------- ------ 32.8/39.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/39.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 11.2 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.6 MB 19.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.6 MB 17.6 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 17.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.3.4
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-2.3.4:
#    ---------------------------------------- 0/2 [numpy]
#       Successfully uninstalled numpy-2.3.4
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    ---------------------------------------- 2/2 [opencv-python]
#
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Edward\miniconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Edward\miniconda3\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
import pytesseract
from pdf2image import convert_from_path
import pandas as pd
import re
import os
import sys

# ==========================================
# 1. CONFIGURACIÓN DE RUTAS (AJUSTA AQUÍ)
# ==========================================

# Ruta al ejecutable de Tesseract (donde lo instalaste)
# Si no está aquí, busca "tesseract.exe" en tu PC y pega la ruta.
TESSERACT_CMD = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

# Ruta a la carpeta 'bin' de Poppler (la que descomprimiste y copiaste)
# IMPORTANTE: Asegúrate de que esta ruta termine en \bin
POPPLER_PATH = r'C:/Program Files/Poppler/poppler-25.12.0/Library/bin'

# Archivo de entrada y salida
PDF_PATH = "../data/raw/20251209-V.pdf"
OUTPUT_EXCEL = "../data/intermediate/LIGIE_Tabla_Final.xlsx"

# ==========================================
# 2. CONFIGURACIÓN DEL MOTOR OCR
# ==========================================

# Validamos que las herramientas existan antes de empezar
if not os.path.exists(TESSERACT_CMD):
    print(f"ERROR: No encuentro Tesseract en: {TESSERACT_CMD}")
    print("Por favor instala Tesseract o corrige la ruta en el código.")
    sys.exit()

if not os.path.exists(POPPLER_PATH):
    print(f"ERROR: No encuentro la carpeta bin de Poppler en: {POPPLER_PATH}")
    print("Por favor verifica donde descomprimiste Poppler.")
    sys.exit()

# Conectamos Tesseract a Python
pytesseract.pytesseract.tesseract_cmd = TESSERACT_CMD

# Expresiones Regulares (El "cerebro" del script)
# Detecta el inicio de una fracción: 8 dígitos (ej: 8409.99.14)
REGEX_CODIGO = re.compile(r"^(\d{4}\.\d{2}\.\d{2})")

# Lista de textos basura para limpiar encabezados y pies de página
TEXTOS_IGNORAR = [
    "CÁMARA DE", "DIPUTADOS", "LXVI LEGISLATURA", "Comisión de Economía", 
    "DICTAMEN RELATIVO", "Página", "CÓDIGO", "DESCRIPCIÓN", "UNIDAD", 
    "INICIATIVA", "EJECUTIVO", "FEDERAL", "CUOTA", "(ARANCEL)", 
    "MODIFICACIÓN", "DICTAMEN", "Hoja", "Anexo", "The following table"
]

# ==========================================
# 3. FUNCIONES DE PROCESAMIENTO
# ==========================================

def es_linea_basura(texto):
    """Filtra encabezados, pies de página y líneas vacías."""
    if not texto: return True
    if len(texto) < 4: return True # Líneas muy cortas suelen ser basura o números de página
    
    texto_upper = texto.upper()
    for basura in TEXTOS_IGNORAR:
        if basura.upper() in texto_upper:
            return True
    return False

def procesar_registro(codigo, descripcion_sucia):
    """
    Toma una descripción larga y extrae la Unidad y las Tasas que suelen estar al final.
    Ejemplo entrada: "Varillas de acero... Kg 35 25"
    Ejemplo salida: Desc="Varillas de acero...", Unidad="Kg", Tasa1="35", Tasa2="25"
    """
    texto_completo = descripcion_sucia.strip()
    
    # Regex inversa: Busca [Unidad] [Tasa] [Tasa] al final de la línea
    # Soporta: Kg, Pza, L, M2, etc. y tasas numéricas o "Ex" (Exento)
    patron_final = re.compile(r"(Kg|Pza|L|M2|Par|Jgo|Mil|Cabeza)\s+([0-9\.]+|Ex\.?)\s+([0-9\.]+|Ex\.?|=|-)$", re.IGNORECASE)
    
    match = patron_final.search(texto_completo)
    
    item = {
        "CODIGO": codigo,
        "DESCRIPCION": texto_completo, # Por defecto todo es descripción
        "UNIDAD": "",
        "ARANCEL_INICIATIVA": "",
        "ARANCEL_DICTAMEN": ""
    }

    if match:
        item["UNIDAD"] = match.group(1)
        item["ARANCEL_INICIATIVA"] = match.group(2)
        item["ARANCEL_DICTAMEN"] = match.group(3)
        # Cortamos la descripción justo antes de donde empiezan los datos numéricos
        item["DESCRIPCION"] = texto_completo[:match.start()].strip()
    
    # Limpieza extra de caracteres que el OCR suele confundir
    item["DESCRIPCION"] = item["DESCRIPCION"].replace('|', '').replace('_', '')
    
    return item

def extraer_ligie_ocr(pdf_path):
    print(f"--- Iniciando proceso para: {pdf_path} ---")
    print("PASO 1: Convirtiendo PDF a imágenes (esto puede tardar unos minutos)...")
    
    try:
        # Convertimos PDF a imágenes de alta resolución (300 DPI)
        pages = convert_from_path(pdf_path, dpi=300, poppler_path=POPPLER_PATH)
    except Exception as e:
        print(f"\nERROR CRÍTICO: Falló la conversión de PDF a Imagen.")
        print(f"Detalle: {e}")
        return pd.DataFrame()

    data = []
    total_paginas = len(pages)
    print(f"PDF cargado exitosamente. Total de páginas: {total_paginas}")
    print("PASO 2: Leyendo texto de las imágenes (OCR)...")

    # Variables temporales para reconstruir párrafos rotos
    temp_codigo = None
    temp_desc = []

    for i, image in enumerate(pages):
        # Escaneamos la imagen buscando texto en español
        # --psm 6 asume un bloque de texto uniforme (ideal para tablas/listas)
        text = pytesseract.image_to_string(image, lang='spa', config='--psm 6')
        
        lines = text.split('\n')
        
        for line in lines:
            line = line.strip()
            
            # Filtros de limpieza
            if es_linea_basura(line): continue
            
            # Corrección OCR: Puntos decimales leídos como comas
            line = line.replace(',', '.') 

            # Intentamos encontrar un código al inicio de la línea
            match = REGEX_CODIGO.match(line)
            
            if match:
                # ¡ENCONTRAMOS UN NUEVO CÓDIGO!
                
                # 1. Guardamos el registro ANTERIOR (si existe)
                if temp_codigo:
                    full_desc = " ".join(temp_desc).strip()
                    registro_procesado = procesar_registro(temp_codigo, full_desc)
                    data.append(registro_procesado)

                # 2. Iniciamos el NUEVO registro
                temp_codigo = match.group(1)
                # Lo que sobra en la línea después del código es parte de la descripción
                resto_linea = line[len(temp_codigo):].strip()
                temp_desc = [resto_linea]
                
            else:
                # NO ES CÓDIGO: Es continuación de la descripción del registro actual
                if temp_codigo:
                    temp_desc.append(line)
        
        # Reporte de progreso cada 10 páginas
        if (i+1) % 10 == 0 or (i+1) == total_paginas:
            print(f"Procesando página {i+1} de {total_paginas}...")

    # Guardar el último registro pendiente al terminar el documento
    if temp_codigo:
        full_desc = " ".join(temp_desc).strip()
        data.append(procesar_registro(temp_codigo, full_desc))

    return pd.DataFrame(data)

# ==========================================
# 4. EJECUCIÓN PRINCIPAL
# ==========================================
if __name__ == "__main__":
    if os.path.exists(PDF_PATH):
        df_resultado = extraer_ligie_ocr(PDF_PATH)
        
        if not df_resultado.empty:
            print("\nPASO 3: Guardando archivo Excel...")
            # Reordenar columnas para que se vea bonito
            cols = ["CODIGO", "DESCRIPCION", "UNIDAD", "ARANCEL_INICIATIVA", "ARANCEL_DICTAMEN"]
            df_resultado = df_resultado[cols]
            
            df_resultado.to_excel(OUTPUT_EXCEL, index=False)
            print(f"¡ÉXITO TOTAL! Archivo guardado como: {OUTPUT_EXCEL}")
            print(f"Se extrajeron {len(df_resultado)} fracciones arancelarias.")
            print("\nMuestra de los primeros 5 datos:")
            print(df_resultado.head())
        else:
            print("El proceso terminó pero no se encontraron datos válidos.")
    else:
        print(f"No encuentro el archivo PDF: {PDF_PATH}")
        print("Asegúrate de poner este script en la misma carpeta que el PDF.")
# Out:
# --- Iniciando proceso para: C:/Users/Edward/Desktop/Bancomext/Tariffs/data/raw/20251209-V.pdf ---
# PASO 1: Convirtiendo PDF a imágenes (esto puede tardar unos minutos)...
# PDF cargado exitosamente. Total de páginas: 190
# PASO 2: Leyendo texto de las imágenes (OCR)...
# Procesando página 10 de 190...
# Procesando página 20 de 190...
# Procesando página 30 de 190...
# Procesando página 40 de 190...
# Procesando página 50 de 190...
# Procesando página 60 de 190...
# Procesando página 70 de 190...
# Procesando página 80 de 190...
# Procesando página 90 de 190...
# Procesando página 100 de 190...
# Procesando página 110 de 190...
# Procesando página 120 de 190...
# Procesando página 130 de 190...
# Procesando página 140 de 190...
# Procesando página 150 de 190...
# Procesando página 160 de 190...
# Procesando página 170 de 190...
# Procesando página 180 de 190...
# Procesando página 190 de 190...
#
# PASO 3: Guardando archivo Excel...
# ¡ÉXITO TOTAL! Archivo guardado como: LIGIE_Tabla_Final.xlsx
# Se extrajeron 2018 fracciones arancelarias.
#
# Muestra de los primeros 5 datos:
#        CODIGO                                        DESCRIPCION UNIDAD  \
# 0  3303.00.01                                  Aguas de tocador.
# 1  3303.00.99
# 2  3304.10.01  Preporgc¡ones para el maguillaje de Kg 50 36 l...
# 3  3304.20.01  Preporoc¡ones para el maquillaje de los ojos. ...
# 4  3304.91.01                  Polvos. incluidos los compactos.
#
#   ARANCEL_INICIATIVA ARANCEL_DICTAMEN
# 0
# 1
# 2
# 3
# 4

# %%
import os
from pdf2image import convert_from_path

# --- CONFIGURACIÓN ---
# Ruta a tu PDF
PDF_PATH = "C:/Users/Edward/Desktop/Bancomext/Tariffs/data/raw/20251209-V.pdf"
# Ruta a la carpeta bin de Poppler (Ajústala si es necesario)
POPPLER_PATH = r'C:/Program Files/Poppler/poppler-25.12.0/Library/bin'
# Carpeta donde se guardarán las imágenes
OUTPUT_FOLDER = "paginas_ligie_img"

def convertir_pdf_a_imagenes():
    if not os.path.exists(OUTPUT_FOLDER):
        os.makedirs(OUTPUT_FOLDER)
        print(f"Carpeta creada: {OUTPUT_FOLDER}")

    print(f"Iniciando conversión de {PDF_PATH}...")
    
    try:
        # Convertimos a 300 DPI (Alta calidad para que el OCR lea bien los puntos)
        pages = convert_from_path(PDF_PATH, dpi=300, poppler_path=POPPLER_PATH)
        
        for i, page in enumerate(pages):
            image_name = f"pag_{i+1:04d}.jpg"
            image_path = os.path.join(OUTPUT_FOLDER, image_name)
            page.save(image_path, "JPEG")
            
            if (i+1) % 10 == 0:
                print(f"Guardada {image_name}...")
                
        print(f"¡Listo! {len(pages)} páginas convertidas en la carpeta '{OUTPUT_FOLDER}'.")
        
    except Exception as e:
        print(f"Error: {e}")
        print("Verifica la ruta de Poppler.")

if __name__ == "__main__":
    convertir_pdf_a_imagenes()
# Out:
# Carpeta creada: paginas_ligie_img
# Iniciando conversión de C:/Users/Edward/Desktop/Bancomext/Tariffs/data/raw/20251209-V.pdf...
# Guardada pag_0010.jpg...
# Guardada pag_0020.jpg...
# Guardada pag_0030.jpg...
# Guardada pag_0040.jpg...
# Guardada pag_0050.jpg...
# Guardada pag_0060.jpg...
# Guardada pag_0070.jpg...
# Guardada pag_0080.jpg...
# Guardada pag_0090.jpg...
# Guardada pag_0100.jpg...
# Guardada pag_0110.jpg...
# Guardada pag_0120.jpg...
# Guardada pag_0130.jpg...
# Guardada pag_0140.jpg...
# Guardada pag_0150.jpg...
# Guardada pag_0160.jpg...
# Guardada pag_0170.jpg...
# Guardada pag_0180.jpg...
# Guardada pag_0190.jpg...
# ¡Listo! 190 páginas convertidas en la carpeta 'paginas_ligie_img'.

# %%
import pytesseract
try:
    from PIL import Image
except ImportError:
    import Image
import pandas as pd
import re
import os
import sys

# ==========================================
# 1. CONFIGURACIÓN
# ==========================================
# Ajusta tu ruta de Tesseract
TESSERACT_CMD = r'C:/Program Files/Tesseract-OCR/tesseract.exe'
# Carpeta donde guardaste las imágenes en el paso anterior
INPUT_FOLDER = "paginas_ligie_img"
OUTPUT_EXCEL = "LIGIE_Base_Datos_Final.xlsx"

# Configurar Tesseract
pytesseract.pytesseract.tesseract_cmd = TESSERACT_CMD

# --- REGLAS DE NEGOCIO ---
# 1. Código: 8 dígitos con puntos
REGEX_INICIO_FILA = re.compile(r"^(\d{4}\.\d{2}\.\d{2})")

# 2. Unidades permitidas (Añade más si faltan)
UNIDADES_VALIDAS = r"(Kg|Pza|L|M2|Par|Jgo|Mil|Cabeza)"

# 3. Cuotas permitidas: Números, decimales, "Ex.", "Ex", o "=" (sin cambios)
# La regex busca: Espacio + Tasa + Espacio + Tasa + Fin de linea
# Se usa re.IGNORECASE para que "kg" o "KG" funcionen igual
REGEX_FINAL_LINEA = re.compile(rf"{UNIDADES_VALIDAS}\s+([0-9\.]+|Ex\.?|=)\s*([0-9\.]+|Ex\.?|=)?$", re.IGNORECASE)

# Lista negra para limpiar basura antes de procesar
TEXTOS_BASURA = [
    "CÁMARA DE", "LXVI LEGISLATURA", "DICTAMEN", "Página", 
    "Comisión de", "INICIATIVA", "EJECUTIVO", "FEDERAL", 
    "CUOTA", "(ARANCEL)", "MODIFICACIÓN", "The following table",
    "Hoja", "Anexo"
]

# ==========================================
# 2. FUNCIONES DE LÓGICA
# ==========================================

def limpiar_texto_ocr(texto):
    """Limpia ruido común del OCR."""
    # Reemplazar pipes o guiones bajos que el OCR confunde con bordes de tabla
    texto = texto.replace('|', ' ').replace('_', ' ')
    # Quitar espacios múltiples
    texto = re.sub(r'\s+', ' ', texto).strip()
    return texto

def es_basura(linea):
    if len(linea) < 3: return True
    for basura in TEXTOS_BASURA:
        if basura.lower() in linea.lower():
            return True
    return False

def procesar_bloque_texto(codigo, texto_acumulado):
    """
    Recibe: "0101.01.01 Caballos vivos reproductores de raza pura. Cabeza Ex. Ex."
    Retorna: Diccionario con campos separados o None si falla.
    """
    # 1. Quitamos el código del inicio para analizar el resto
    contenido = texto_acumulado.replace(codigo, "", 1).strip()
    
    # 2. Buscamos Unidad y Tasas al FINAL del texto (Estrategia Inversa)
    match = REGEX_FINAL_LINEA.search(contenido)
    
    if match:
        unidad = match.group(1)      # Ej: Kg
        tasa_1 = match.group(2)      # Ej: 35
        tasa_2 = match.group(3)      # Ej: 25 (puede ser None)
        
        # Si la tasa 2 está vacía, asumimos que es igual o nula, ajustamos según lógica
        if tasa_2 is None: tasa_2 = "" 

        # 3. La descripción es todo lo que está ANTES de lo que encontró el Regex
        fin_descripcion_idx = match.start()
        descripcion = contenido[:fin_descripcion_idx].strip()
        
        # 4. Regla de validación: Descripción debe terminar en punto
        # Si el OCR falló y puso una coma, lo corregimos. Si no tiene nada, le ponemos punto.
        if descripcion.endswith(','):
            descripcion = descripcion[:-1] + "."
        elif not descripcion.endswith('.'):
            # Opcional: Forzar el punto o marcar error. Aquí lo forzamos para que sea 'usable'
            descripcion += "."

        # Imprimir para monitoreo en tiempo real (Feedback visual)
        print(f"  [OK] {codigo} | Unid: {unidad} | T1: {tasa_1} | T2: {tasa_2} | Desc: {descripcion[:30]}...")
        
        return {
            "CODIGO": codigo,
            "DESCRIPCION": descripcion,
            "UNIDAD": unidad,
            "TASA_INICIATIVA": tasa_1,
            "TASA_DICTAMEN": tasa_2,
            "ESTATUS": "COMPLETO"
        }
    else:
        # Si falla el regex del final, es porque el OCR leyó mal la unidad o las tasas
        print(f"  [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código {codigo}")
        print(f"     Texto crudo: {contenido}")
        return {
            "CODIGO": codigo,
            "DESCRIPCION": contenido, # Guardamos todo junto para corrección manual
            "UNIDAD": "REVISAR",
            "TASA_INICIATIVA": "REVISAR",
            "TASA_DICTAMEN": "REVISAR",
            "ESTATUS": "ERROR_OCR"
        }

# ==========================================
# 3. BUCLE PRINCIPAL DE EXTRACCIÓN
# ==========================================

def main_extraction():
    if not os.path.exists(INPUT_FOLDER):
        print("Error: No existe la carpeta de imágenes. Ejecuta el Script 1 primero.")
        return

    archivos = sorted(os.listdir(INPUT_FOLDER))
    # Filtrar solo jpgs
    archivos = [f for f in archivos if f.endswith(".jpg")]
    
    registros_finales = []
    
    # Variables de estado para la máquina de estados
    buffer_codigo = None
    buffer_texto = []

    print(f"Iniciando extracción sobre {len(archivos)} imágenes...")

    for i, archivo in enumerate(archivos):
        ruta_img = os.path.join(INPUT_FOLDER, archivo)
        
        # OCR de la página
        # --psm 6 asume un bloque de texto uniforme (clave para tablas sin bordes)
        texto_crudo = pytesseract.image_to_string(Image.open(ruta_img), lang='spa', config='--psm 6')
        
        lineas = texto_crudo.split('\n')
        
        print(f"--> Procesando {archivo} ({len(lineas)} líneas detectadas)")

        for linea in lineas:
            linea_limpia = limpiar_texto_ocr(linea)
            
            if es_basura(linea_limpia):
                continue

            # ¿Empieza con un código arancelario?
            match_codigo = REGEX_INICIO_FILA.match(linea_limpia)

            if match_codigo:
                # 1. Si ya teníamos un buffer lleno, procesamos el registro ANTERIOR
                if buffer_codigo:
                    texto_completo_anterior = " ".join(buffer_texto)
                    fila = procesar_bloque_texto(buffer_codigo, texto_completo_anterior)
                    if fila: registros_finales.append(fila)

                # 2. Iniciamos NUEVO registro
                buffer_codigo = match_codigo.group(1)
                buffer_texto = [linea_limpia] # Guardamos la línea entera, luego limpiaremos el código
            
            else:
                # 3. Si no es código, es continuación de la descripción del actual
                if buffer_codigo:
                    buffer_texto.append(linea_limpia)

    # Procesar el último registro pendiente al finalizar los archivos
    if buffer_codigo:
        texto_completo_anterior = " ".join(buffer_texto)
        fila = procesar_bloque_texto(buffer_codigo, texto_completo_anterior)
        registros_finales.append(fila)

    # ==========================================
    # 4. EXPORTACIÓN
    # ==========================================
    if registros_finales:
        df = pd.DataFrame(registros_finales)
        
        # Filtro final de calidad: No puede haber vacíos en columnas críticas
        # (Aunque mi lógica rellena con "REVISAR", aquí podrías filtrar esos si quisieras)
        
        df.to_excel(OUTPUT_EXCEL, index=False)
        print("\n" + "="*40)
        print(f"PROCESO TERMINADO. Datos guardados en: {OUTPUT_EXCEL}")
        print(f"Registros extraídos: {len(df)}")
        print(f"Registros con error de formato: {len(df[df['ESTATUS'] == 'ERROR_OCR'])}")
        print("="*40)
    else:
        print("No se extrajo ningún registro. Revisa la configuración de Tesseract.")

if __name__ == "__main__":
    main_extraction()
# Out:
# Iniciando extracción sobre 190 imágenes...
# --> Procesando pag_0001.jpg (14 líneas detectadas)
# --> Procesando pag_0002.jpg (38 líneas detectadas)
# --> Procesando pag_0003.jpg (38 líneas detectadas)
# --> Procesando pag_0004.jpg (47 líneas detectadas)
# --> Procesando pag_0005.jpg (39 líneas detectadas)
# --> Procesando pag_0006.jpg (42 líneas detectadas)
# --> Procesando pag_0007.jpg (36 líneas detectadas)
# --> Procesando pag_0008.jpg (30 líneas detectadas)
# --> Procesando pag_0009.jpg (28 líneas detectadas)
# --> Procesando pag_0010.jpg (30 líneas detectadas)
# --> Procesando pag_0011.jpg (36 líneas detectadas)
# --> Procesando pag_0012.jpg (32 líneas detectadas)
# --> Procesando pag_0013.jpg (1 líneas detectadas)
# --> Procesando pag_0014.jpg (32 líneas detectadas)
# --> Procesando pag_0015.jpg (37 líneas detectadas)
# --> Procesando pag_0016.jpg (35 líneas detectadas)
# --> Procesando pag_0017.jpg (43 líneas detectadas)
# --> Procesando pag_0018.jpg (44 líneas detectadas)
# --> Procesando pag_0019.jpg (42 líneas detectadas)
# --> Procesando pag_0020.jpg (41 líneas detectadas)
# --> Procesando pag_0021.jpg (40 líneas detectadas)
# --> Procesando pag_0022.jpg (40 líneas detectadas)
# --> Procesando pag_0023.jpg (42 líneas detectadas)
# --> Procesando pag_0024.jpg (40 líneas detectadas)
# --> Procesando pag_0025.jpg (44 líneas detectadas)
# --> Procesando pag_0026.jpg (40 líneas detectadas)
# --> Procesando pag_0027.jpg (41 líneas detectadas)
# --> Procesando pag_0028.jpg (44 líneas detectadas)
# --> Procesando pag_0029.jpg (41 líneas detectadas)
# --> Procesando pag_0030.jpg (44 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3303.00.01
#      Texto crudo: Aguas de tocador.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3303.00.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3304.10.01
#      Texto crudo: Preporgc¡ones para el maguillaje de Kg 50 36 los labios.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3304.20.01
#      Texto crudo: Prep oroc¡ones para el maquillaje de los ojos. pedicuros.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3304.91.01
#      Texto crudo: Polvos, incluidos los compactos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3304.99.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3304.29.99
#      Texto crudo:
# --> Procesando pag_0031.jpg (47 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3305.10.01
#      Texto crudo: y Competitividad 5 LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN -- p
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3305.20.01
#      Texto crudo: Prepproc¡ones para ondulación o Kg 35 25 desrizado permanentes.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3305.30.01
#      Texto crudo: Lacas para el cabello.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3305.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3306.10.01
#      Texto crudo: Hilo utilizado para limpieza de los
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3306.20.02
#      Texto crudo: espacios interdentales (hilo dental).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3306.90.99
#      Texto crudo: 23307.10.01 Preporoc¡ones¡pora ofe¡ 'for o para Kg 35 25 antes o después del afeitado. say uay TaT Kg 35 25 preparaciones para el baño. "Agarbatti" y demás preparaciones
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3307.41.01
#      Texto crudo: odoríferas que actúan por Kg 35 25 combustión.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3307.49.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3307.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3401.19.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3401.20.01
#      Texto crudo: Jabón en otras formas. Productos y preparaciones orgánicos tensoactivos para el lavado de la
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3401.30.01
#      Texto crudo: piel, líquidos o en crema, Kg 35 25 acondicionados para la venta al por menor, aunque contengan jabón. preparaciones para fregar.
#   [OK] 3916.10.02 | Unid: Kg | T1: 119 | T2: 5 | Desc: De polímeros de etileno....
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3916.20.03
#      Texto crudo: De polímeros de cloruro de vinilo.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3916.90.91
#      Texto crudo: De los demás plásticos. “ Tripas artificiales de proteínas
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.10.05
#      Texto crudo: endurecidas o d e plásticos Kg 7 celulósicos. á
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.21.08
#      Texto crudo: De polímeros de etileno.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.22.03
#      Texto crudo: De polímeros de propileno. “
# --> Procesando pag_0032.jpg (48 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.23.04
#      Texto crudo: De polímeros de cloruro de vinilo. “ y Competitividad £ LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN ECC
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.29.91
#      Texto crudo: De los demás plósticos. Kg 1 7 Tubos flexibles para una presión 97173191 superior o igual a 27.6 MPa. “ 39173291 Los demás, sin rgforz< :¡r ñi comb3nor Kg 7 con otras materias, sin accesorios. Tubería de materias plásticas
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.33.01
#      Texto crudo: o r'(¡f¡c¡oles, hos?a de 20 mm de Kg 35 25 diámetro exterior, con goteras integradas, para riego agrícola.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3917.33.99
#      Texto crudo: 3917.9999 losdemás. — K í"“w 7 3917.4001 [accesorios. — yK , 7
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3918.10.02
#      Texto crudo: De polímeros de cloruro de vinilo.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3918.90.91
#      Texto crudo: De los demás plásticos. 39191001 En rollos de anchura inferior o igual a “ 20 cm.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3919.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.10.05
#      Texto crudo: De polímeros de etileno. “
#   [OK] 3920.20.05 | Unid: Kg | T1: 19 | T2: 5 | Desc: De polímeros de propileno....
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.30.04
#      Texto crudo: De polímeros de estireno. “
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.43.03
#      Texto crudo: Con un cqnten¡do de plastificantes Kg 5 superior o igual al 6% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.49.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.51.01
#      Texto crudo: De poli[metacrilato de metilo). Kg 119 —7 —
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.59.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.61.01
#      Texto crudo: De policarbonatos. “
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.62.02
#      Texto crudo: Películas de poliéster biorientado. “
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.62.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.63.03
#      Texto crudo: De poliésteres no saturados. Kg m —7
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.69.91
#      Texto crudo: De los demás poliésteres. Kg m 5
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.71.01
#      Texto crudo: De celulosa regenerada. Kg 19 —7 — y
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.73.02
#      Texto crudo: De acetato de celulosa. “ celulosa.
# --> Procesando pag_0033.jpg (45 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.91.01
#      Texto crudo: De poli(vinilbutiral). Kg 10 —7 y Competitividad Z LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE m— L XV LEGIS URA =.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.92.02
#      Texto crudo: De poliamidas. F K m 7
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.94.01
#      Texto crudo: De resinas fenólicas. “
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3920.99.91
#      Texto crudo: De los demás plásticos. e m o 7
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3921.11.01
#      Texto crudo: De polímeros de estiren o.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3921.12.01
#      Texto crudo: De polímeros de cloruro de vinilo. “
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3921.13.02
#      Texto crudo: De poliuretanos. —Kg m 7
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3921.14.01
#      Texto crudo: De celulosa regenerada. “
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3921.19.91
#      Texto crudo: De los demás plásticos. Kg 119 —7 — De poliéster metalizados con
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3921.90.09
#      Texto crudo: anchura superior o ¡guol a 35 mm, Kg 35 25 con un espesor inferior a 100 micrones. 399219099 lasdemás. — K P M'"" 7 lavabos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3922.20.01
#      Texto crudo: Asientos y tapas de inodoros.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3922.90.99
#      Texto crudo: similares.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.21.01
#      Texto crudo: De polímeros de etileno. Kg 190 —7 —
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.29.91
#      Texto crudo: De los demás plásticos. Kg 190 —7 —
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.30.02
#      Texto crudo: Bombonas (fjomojgopos), botellas, Kg 35 35 frascos y artículos similares. "Casetes" o cartuchos para
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.40.02
#      Texto crudo: embobinar cintas magnéticas de Kg 10 7 sonido de anchura inferior a 13 mm.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.40.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.50.01
#      Texto crudo: quon gs, tapas, copsulos y demás Kg 35 25 dispositivos de cierre.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3923.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3924.10.01
#      Texto crudo: VG]I IICI. y demás artículos para el Kg 35 25 ¡ servicio de mesa o de cocina.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3924.90.01
#      Texto crudo: Mangos para maquinillas de afeitar. “
# --> Procesando pag_0034.jpg (52 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3924.90.99
#      Texto crudo: Comision de Economia, Comercio y Competitividad - LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN RC Depósitos, cisternas, cubas y
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3925.10.01
#      Texto crudo: recipientes análogos, de capacidad Kg 85 25 superior a 300 . 3925 20.01 Puertas, ventanas, y sus marcos, Kg 35 25 contramarcos y umbrales. Contraventanas, persianas (incluidas
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3925.30.01
#      Texto crudo: las venecianas) y artículos similares, y Kg 35 25 sus partes.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3925.90.99
#      Texto crudo: 3926.10,01 Aftículos de oficina y artículos escolares.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.20.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.40.01
#      Texto crudo: Estatuillas y demás artículos de adorno.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.01
#      Texto crudo: Mangos para herramientas de mano.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.04
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.06
#      Texto crudo: Loncheras; cantimplora s.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.07
#      Texto crudo: Modelos o patrones.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.08
#      Texto crudo: Hormas para calzado.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.11
#      Texto crudo: Protectores para el sentido auditivo.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.13
#      Texto crudo: Cinchos fijadores o abrazaderas,
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.14
#      Texto crudo: egce pfo lo recon ocvble como Kg 35 25 diseñados exclusivamente para uso automotriz.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.15
#      Texto crudo: Almácigas, con oquedades Kg 25 1 perforadas. Marcas para asfalto, postes reflejantes y/o dispositivos de
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.18
#      Texto crudo: advertencia (triángulos de Kg 39 25 seguridad), de resina plástica, para la señalización vial.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.19
#      Texto crudo: ¡ Láminas perforadas o troqueladas de
# --> Procesando pag_0035.jpg (51 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.27
#      Texto crudo: pol¡(ehleno)¡y/o poli(propileno), aun Kg 35 25 cuando estén coloreadas, metalizadas o laqueadas. y Competitividad A LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN en
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 3926.90.29
#      Texto crudo: 39269099 lasdemás. K r"“ — 7 De los tipos utilizados en automóviles
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4011.10.10
#      Texto crudo: de i u.r srrjlo (mcl&ud95 Iqs del tipo , Pza 35 35 familiar ('break" o "station wagon”) y los de carreras).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4011.20.04
#      Texto crudo: Con diámetro mte¡30r superior a 44.45 o 35 25 em, de construcción radial.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4011.20.05
#      Texto crudo: Con diámetro ntg[ or superior a 44.45 Pza 35 25 cm, de construcción diagonal.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4011.20.06
#      Texto crudo: Con diámetro interior inferior o igual a Pza 35 44.45 cm.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4011.70.03
#      Texto crudo: De diámetro interior superior a 35 cm. — 40117099 losdemás. — mal - s
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4016.93.04
#      Texto crudo: Juntas o empaquetaduras. Artículos de talabartería o guarnicionería para todos los
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4201.00.01
#      Texto crudo: on¡moles (incluidos los tiros, Tro¡llos,t Pza 35 25 rodilleras, bozales, sudaderos, alforjas, abrigos para perros y artículos similares), de cualquier materia.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.11.01
#      Texto crudo: Con la superficie exterior de cuero -- 35 25 natural o cuero regenerado.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.12.03
#      Texto crudo: Conla spperf¡qe exterior de plástico Pza 35 25 o materia textil.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.19.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.21.01
#      Texto crudo: Con la superficie exterior de cuero B 35 25 natural o cuero regenerado. plástico o materia textil.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.29.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.31.01
#      Texto crudo: Con la superficie exterior de cuero Bina 35 25 Y natural o cuero regenerado. plástico o materia textil.
# --> Procesando pag_0036.jpg (50 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.39.99
#      Texto crudo: X 1 y Competitividad LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA DESCRIPCIÓN ia
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.91.01
#      Texto crudo: Con la superficie exterior de cuero Pza 35 25 natural o cuero regenerado. plástico o materia textil. 1
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4202.99.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4203.21.01
#      Texto crudo: D¡s engdos especialmente para la — 35 25 práctica del deporte.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4203.29.01
#      Texto crudo: Para protección contra radiaciones.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4203.29.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4203.30.02
#      Texto crudo: Cintos, cinturones y bandoleras.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4205.00.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4802.55.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4802.56.99
#      Texto crudo: Los demás, de peso superior o igual a
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4802.57.91
#      Texto crudo: 40 9/m2 pero inferior o igual a 150 Kg 35 35 g9/m2.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4802.58.04
#      Texto crudo: De peso superior a 150 g/m2.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4802.61.03
#      Texto crudo: En bobinas (rollos).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4804.39.99
#      Texto crudo: Blanqueados uniformemente en la masa y con un contenido de fibras a2 ea ENEO Kg 35 35 procedimiento químico superior al 95% en peso del contenido total de fibra.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4805.24.02
#      Texto crudo: De peso inferior o igual a 150 g/m2. —
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4805.25.02
#      Texto crudo: De peso superior a 150 g/m2.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4810.13.07
#      Texto crudo: En bobinas (rollos).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4810.29.99
#      Texto crudo: Blanqueados uniformemente en la masa y con un contenido de fibras amasen; SeTadaa ootenda po Kg 35 25 procedimiento químico superior al y 95% en peso del contenido total de fibra, de peso superior a 150 g/m*.
# --> Procesando pag_0037.jpg (51 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4810.39.99
#      Texto crudo: y Competitividad z LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN N
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4810.92.01
#      Texto crudo: Multicapas.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4810.99.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4811.41.02
#      Texto crudo: En tiras o en bobinas (rollos).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4811.49.01
#      Texto crudo: En tiras o en bobinas (rollos). — Papel para decorar y revestimientos similares de paredes, constituidos por papel recubierto o revestido, en la
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4814.20.01
#      Texto crudo: cara vista, con una capa de plástico Kg 35 25 graneada, gofrada, coloreada, impresa con motivos o decorada de otro modo.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4814.90.02
#      Texto crudo: Papel granito ["ingrain").
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4814.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4816.20.01
#      Texto crudo: Papel autocopia.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4816.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4817.10.01
#      Texto crudo: Sobres carta, tarjetas postales sin
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4817.20.01
#      Texto crudo: tilustrar y tarjetas para Kg 39 25 correspondencia. Cajas, bolsas y presentaciones similares de papel o cartón, con un PE surtido de artículos de Kg . % correspondencia.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4818.20.01
#      Texto crudo: Pañuelos, toallitas de desmaqauillar y Kg 35 25 toallas.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4818.30.01
#      Texto crudo: Manteles y servilletas. asta:00 edas y aomplemeos Kg 35 25 1 (accesorios), de vestir.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4818.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4819.10.01
#      Texto crudo: Cajas de papel o cartón corrugado.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4819.20.02
#      Texto crudo: Cajas y cortqno¡gs, plegables, de Kg 35 25 papel o cartón, sin corrugar.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4819.30.01
#      Texto crudo: Sacos (bols.os) con una anchura en la Kg 35 25 b base superior o igual a 40 cm.
# --> Procesando pag_0038.jpg (47 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4819.40.91
#      Texto crudo: Los demás sacos [bolsas); bolsitas y / J cucuruchos. W y Competitividad £ LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE CÓDIGO DESCRIPCIÓN ENV
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4819.50.91
#      Texto crudo: Los demás envases, incluidas las Kg 35 25 fundas para discos. similares. Libros registro, libros de contabilidad, talonarios (de notas, pedidos o
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4820.10.02
#      Texto crudo: recibos), boques memorandos, Kg 30 25 bloques de papel de cartas, agendas y artículos similares. Clasificadores, encuadernaciones
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4820.30.01
#      Texto crudo: (excepto las cu b¡ertos para libros), Kg 35 25 carpetas y cubiertas para documentos. Formularios en paquetes o plegados
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4820.40.01
#      Texto crudo: ("manifold"), aunque lleven papel Kg 39 25 carbón (carbónico). colecciones.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4820.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4821.10.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4821.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4823.20.02
#      Texto crudo: Papel y cartón filtro. Papel diagrama para aparatos
#   [OK] 4823.40.01 | Unid: Kg | T1: 3 | T2: 25 | Desc: registradores, en bobinas (rol...
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4823.69.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4823.70.03
#      Texto crudo: Empaquetaduras.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4823.70.99
#      Texto crudo: 4823.90,11 Para protección de películas 30 fotográficas.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 4823.90.99
#      Texto crudo: Hilados de seda (excepto los hilados
# --> Procesando pag_0039.jpg (49 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5004.00.01
#      Texto crudo: de desp erd¡c¡os de seda) sin Kg 35 25 v acondicionar para la venta al por menor. t y Competitividad - LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN ISO Hilados de desperdicios de seda sin
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5005.00.01
#      Texto crudo: acondicionar para la venta al por Kg 35 25 menor.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5007.10.01
#      Texto crudo: Tejidos de borrilla. Los demás tejidos con un contenido
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5007.20.91
#      Texto crudo: d e ;edo o de desperd¡c¡os Qe se do, Me 35 25 distintos de la borrilla, superior o igual al 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5007.20.91
#      Texto crudo: Los demás tejidos. ordinario.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5105.10.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5105.21.01
#      Texto crudo: “Lana peinada a granel".
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5105.29.99
#      Texto crudo: lasdemás. — K 1 ' * 5105:21,01 De:cabre de Guchemira.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5105.39.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5105.40.01
#      Texto crudo: Pelo ordinario cardado o peinado.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5106.10.01
#      Texto crudo: Con un contenido de lana superior o Kg 35 25 igual al 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5106.20.01
#      Texto crudo: C<z7n un contenido de lana inferior al Kg 35 25 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5107.10.01
#      Texto crudo: Flon un contenido de lana superior o Kg 50 36 igual al 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5107.20.01
#      Texto crudo: Cc;7n un contenido de lana inferior al Kg 35 25 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5108.10.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5108.20.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5109.10.01
#      Texto crudo: Con un co n1en¡do de lana o pelo fino Kg 35 25 superior o igual al 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5109.90.99
#      Texto crudo: . Hilados de pelo ordinario o de crin (incluidos los hilados de crin
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5110.00.01
#      Texto crudo: entorchados), aunque estén Kg 35 25 W acondicionados para la venta al por menor. S
# --> Procesando pag_0040.jpg (47 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5111.11.02
#      Texto crudo: De peso inferior o igual a 300 g/m*. X y Competitividad A LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIA$ DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN ee
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5111.19.99
#      Texto crudo: Los demás, mezclados exclusiva o
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5111.20.91
#      Texto crudo: principalmente con filamentos M? 35 25 sintéticos o artificiales. Los demás, mezclados exclusiva o
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5111.30.91
#      Texto crudo: principalmente con fibras sintéticas o M? 35 25 artificiales discontinuas.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5111.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5112.11.02
#      Texto crudo: De peso inferior o igual a 200 g/m*.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5112.19.99
#      Texto crudo: Los demás, mezclados exclusiva o
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5112.20.91
#      Texto crudo: principalmente con filamentos M? 35 25 sintéticos o artificiales. Los demás, mezclados exclusiva o
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5112.30.91
#      Texto crudo: principalmente con fibras sintéticas o M* 35 25 artificiales discontinuas.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5112.90.99
#      Texto crudo: 5204.20,01 Acondicionado para la venta al por menor. De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.11.01
#      Texto crudo: decitex (inferior o igual al número Kg 39 25 métrico 14). De título inferior a 714.29 decitex pero
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.12.01
#      Texto crudo: superior o] gugl a 232.5.6 dec¡tex Kg 35 25 (superior al número métrico 14 pero inferior o igual al número métrico 43). De título inferior a 232.56 decitex pero
# --> Procesando pag_0041.jpg (51 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.13.01
#      Texto crudo: superior o gugl a 192.3 31 dec¡fex Kg 35 25 (superior al número métrico 43 pero j inferior o igual al número métrico 52). De título inferior a 192.31 decitex pero 5005.1401 Upeloraiguala 125 deciar Kg 35 25 > (superior al número métrico 52 pero inferior o igual al número métrico 80). y Competitividad r LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN SR b
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.15.01
#      Texto crudo: De f 'ru lo nfer[or a l25 Sjgc¡fex Kg 35 25 (superior al número métrico 80). De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.21.01
#      Texto crudo: decitex (inferior o igual al número Kg 35 23 métrico 14). De título inferior a 714.29 decitex pero
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.22.01
#      Texto crudo: superior o lgugl a 232..*'36 dec¡fex Kg 35 25 (superior al número métrico 14 pero inferior o igual al número métrico 43). De título inferior a 232.56 decitex pero 5205-23.01 superior o gugl a l92.í%1 dec¡tex Kg 35 25 (superior al número métrico 43 pero … inferior o igual al número métrico 52). De título inferior a 192.31 decitex pero sxs.2001 Uperorogua a 125 aua Kg 35 25 (superior al número métrico 52 pero inferior o igual al número métrico 80). De título inferior a 125 decitex pero
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.26.01
#      Texto crudo: superior o gugl a 106.338 decutex Kg 35 25 (superior al número métrico 80 pero inferior o igual al número métrico 94). De título inferior a 106.38 decitex pero i superior o igual a 83.33 decitex ¡
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.27.01
#      Texto crudo: (superior al número métrico 94 pero Kg 35 25 inferior o igual al número métrico 120). 520528.01 De htglo infer[or a 83.3: 3 c 1ecitex Kg 35 25 (superior al número métrico 120). De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.31.01
#      Texto crudo: dec¡'fex por hilo sepcgllo (inferior o Kg 35 igual al número métrico 14 por hilo sencillo). ¿ De título inferior a 714.29 decitex pero superior o igual a 232.56 decitex, por
# --> Procesando pag_0042.jpg (48 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.32.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 14 pero inferior o igual al número métrico 43, por hilo sencillo). x y Compeltitividad e LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN NE De título inferior a 232.56 decitex pero superior o igual a 192.31 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.33.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 métrico 43 pero inferior o igual al número métrico 52, por hilo sencillo). De título inferior a 192.31 decitex pero superior o igual a 125 decitex, por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.34.01
#      Texto crudo: sencillo (superior al número métrico Kg 35 52 pero inferior o igual al número métrico 80, por hilo sencillo). De título inferior a 125 decitex por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.35.01
#      Texto crudo: sencillo (superior al número métrico Kg DD 80 por hilo sencillo). De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.41.01
#      Texto crudo: decitex por hilo sepcíllo (inferior o Kg 35 25 igual al número métrico 14 por hilo sencillo). De título inferior a 714.29 decitex pero superior o igual a 232.56 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.42.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 14 pero inferior o igual al 1 número métrico 43, por hilo sencillo). De título inferior a 232.56 decitex pero superior o igual a 192.31 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.43.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 43 pero inferior o igual al número métrico 52, por hilo sencillo). De título inferior a 192.31 decitex pero superior o igual a 125 decitex, por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.44.01
#      Texto crudo: sencillo (superior al número métrico Kg 39 25 52 pero inferior o igual al número métrico 80, por hilo sencillo). De título inferior a 125 decitex pero i superior o igual a 106.38 decitex, por
# --> Procesando pag_0043.jpg (50 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.46.01
#      Texto crudo: hilo sencillo (superior al número Kg 33 25 métrico 80 pero inferior o igual al número métrico 94, por hilo sencillo). y Competitividad - LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN ON De título inferior a 106.38 decitex pero superior o igual a 83.33 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.47.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 94 pero inferior o igual al 1 número métrico 120, por hilo sencillo). De título inferior a 83.33 decitex por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5205.48.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 120 por hilo sencillo). . De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.11.01
#      Texto crudo: decitex ([inferior o igual al número Kg 35 25 métrico 14). De título inferior a 714.29 decitex pero
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.12.01
#      Texto crudo: superior o gugl a 232.€6 FÍGCIÍGX Kg 35 25 (superior al número métrico 14 pero inferior o igual al número métrico 43). De título inferior a 232.56 decitex pero
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.13.01
#      Texto crudo: SUperior o gugl a I92.C?l dec¡'fex Kg 35 (superior al número métrico 43 pero inferior o igual al número métrico 52). De título inferior a 192.31 decitex pero … 5204:14.01 UESNO! O10UAl a TS CeciEr Kg 35 25 (superior al número métrico 52 pero inferior o igual al número métrico 80).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.15.01
#      Texto crudo: De htu lo ¡nfer[or a l25 degfex Kg 35 superior al número métrico 80). De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.21.01
#      Texto crudo: decitex (inferior o igual al número Kg 35 métrico 14). De título inferior a 714.29 decitex pero 5206.22.0] SUperior o gugl a 232.¿?6 .dec11ex Kg 35 25 (superior al número métrico 14 pero inferior o igual al número métrico 43). a De título inferior a 232.56 decitex pero
# --> Procesando pag_0044.jpg (46 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.23.01
#      Texto crudo: superior o gugl a 192.C%I decnºex Kg 35 25 (superior al número métrico 43 pero inferior o igual al número métrico 52). y Competitividad LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA DESCRIPCIÓN INICIATVA — mopinicación De título inferior a 192.31 decitex pero 52062401 superic >r o ¡gu c¡l a l25 eritex Kg 35 25 (superior al número métrico 52 pero inferior o igual al número métrico 80). (superior al número métrico 80). De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.31.01
#      Texto crudo: Qecitex por hilo serjch o (inferiorg Kg 35 igual al número métrico 14 por hilo sencillo). De título inferior a 714.29 decitex pero superior o igual a 232.56 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.32.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 14 pero inferior o igual al número métrico 43, por hilo sencillo). De título inferior a 232.56 decitex pero superior o igual a 192.31 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.33.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 43 pero inferior o igual al número métrico 52, por hilo sencillo). De título inferior a 192.31 decitex pero superior o igual a 125 decitex, por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.34.01
#      Texto crudo: sencillo (superior al número métrico Kg 35 25 52 pero inferior o igual al número métrico 80, por hilo sencillo). De título inferior a 125 decitex por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.35.01
#      Texto crudo: sencillo (superior al número métrico Kg 39 28 80 por hilo sencillo). De título superior o igual a 714.29
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.41.01
#      Texto crudo: dec¡fex por hilo sepcíllo (inferior o Kg 35 25 igual al número métrico 14 por hilo sencillo). De título inferior a 714.29 decitex pero superior o igual a 232.56 decitex, por
# --> Procesando pag_0045.jpg (50 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.42.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 € métrico 14 pero inferior o igual al número métrico 43, por hilo sencillo). y Compeltitividad e LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE CÓDIGO DESCRIPCIÓN UNIDAD —ncianva E A De título inferior a 232.56 decitex pero superior o igual a 192.31 decitex, por
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.43.01
#      Texto crudo: hilo sencillo (superior al número Kg 35 25 métrico 43 pero inferior o igual al número métrico 52, por hilo sencillo). De título inferior a 192.31 decitex pero superior o igual a 125 decitex, por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.44.01
#      Texto crudo: sencillo (superior al número métrico Kg 35 25 52 pero inferior o igual al número métrico 80, por hilo sencillo). De título inferior a 125 decitex por hilo
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5206.45.01
#      Texto crudo: sencillo (superior al número métrico Kg 35 29 80 por hilo sencillo).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5207.10.01
#      Texto crudo: Con un cqnten¡do d537 algodón Kg 35 25 superior o igual al 85% en peso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5207.90.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.11.01
#      Texto crudo: pe l gomfento tafetán, de peso M? 35 35 inferior o igual a 100 g/m*. cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.21.01
#      Texto crudo: De I¡gomgnto tafetán, de peso M? 35 35 inferior o igual a 100 g/m?.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.23.01
#      Texto crudo: De ligamento sarga, mg:lu¡dg el M: 35 cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.31.01
#      Texto crudo: pe I gomgnto tafetán, de peso NE 35 inferior o igual a 100 g/m*.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.41.01
#      Texto crudo: pe I¡ gamgnto tafetán, de peso M? 35 35 inferior o igual a 100 g/m*.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.49.91
#      Texto crudo: Los demás tejidos. —m - a
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.51.01
#      Texto crudo: pe I gom enfo tafetán, de peso M? 35 25 inferior o igual a 100 g/m*.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.52.01
#      Texto crudo: De I g omento tafetán, de peso M? 35 25 superior a 100 g/m”. 1
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5208.59.91
#      Texto crudo: Los demás tejidos. m - 3 15209.11.01 De ligamento tafeián.
# --> Procesando pag_0046.jpg (44 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.12.01
#      Texto crudo: De ligamento sarga, mc : u¡dc > el M? 35 25 ¿ cruzado, de curso inferior o igual a 4. y Competitividad á LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE — EGISLATURA =-= CÓDIGO DESCRIPCIÓN UNIDAD IICATVA — monricación
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.21.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.22.01
#      Texto crudo: De ligamento sarga, mc :lu¡dc > el M? 35 5 cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.29.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.31.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.32.01
#      Texto crudo: De ligamento sarga, mg: u¡dg el M? 35 25 cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.39.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.41.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.42.04
#      Texto crudo: Tejidos de mezclilla ("denim"). Los demás tejidos de ligamento
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.43.91
#      Texto crudo: sarga, incluido el cruzado, de curso M? 39 29 inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.51.01
#      Texto crudo: De ligamento tafetán. cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5209.59.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.11.02
#      Texto crudo: De ligamento tafetán. M - — 3
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.19.91
#      Texto crudo: Los demás tejidos. m - 3
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.21.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.29.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.31.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.32.01
#      Texto crudo: De ligamento sarga, inc : u¡d9 el M? 35 25 cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.41.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.49.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.51.01
#      Texto crudo: De ligamento tafetán.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5210.59.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.11.02
#      Texto crudo: De ligamento tafetán. 52111201 De ligamento sarga, ¡nc :luíd9 el M? 35 25 y ' cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.20.04
#      Texto crudo: Blanqueados.
# --> Procesando pag_0047.jpg (47 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.31.01
#      Texto crudo: De ligamento tafetán. M - — 35 y Competitividad ; LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN NA T
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.32.01
#      Texto crudo: De ligamento sarga, mc :lu¡dg el M? 35 35 cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.39.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.41.01
#      Texto crudo: De ligamento tafetán. M - a5
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.51.01
#      Texto crudo: De ligamento tafetán. r
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.52.01
#      Texto crudo: De ligamento sarga, mc :lu¡d< ) el M? 35 25 cruzado, de curso inferior o igual a 4.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5211.59.91
#      Texto crudo: Los demás tejidos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5212.11.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5212.12.01
#      Texto crudo: Blanqueados. m - 3
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5212.13.01
#      Texto crudo: reñido. M - 3
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 5212.14.01
#      Texto crudo: Con hilados de distintos colores. M - — 835
# ...
#      Texto crudo: transportador, acoplamientos hidráulicos y/o Pza J6 cuello de ganso y/o motor de accionamiento hidráulico del equipo. 92014.10.03 reconocibles como diseñadas exclusivamente Pza 25 para uso automotriz.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9029.20.06
#      Texto crudo: oficinas. — REE
# --> Procesando pag_0178.jpg (47 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.30.01
#      Texto crudo: oficinas, excepto lo comprendido en la fracción Pza 25 arancelaria 9403.30.02. Q y Competitividad - LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIA$ DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE DESCRIPCIÓN IMPUESTO DE IMPORTACIÓN Llamados “estaciones de trabajo", reconocibles como diseñados para alojar un sistema de
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.30.02
#      Texto crudo: compufg personal, con fen¡endo por lo menos: Pza 25 una cubierta para monitor, una cubierta para teclado y una cubierta para la unidad central de proceso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.40.01
#      Texto crudo: Mue:bles de madera de los tipos utilizados en cocinas.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.50.01
#      Texto crudo: Mueb'les.de madera de los tipos utilizados en Pza 25 dormitorios. Mesas, reconocibles como diseñadas
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 7403.60.01
#      Texto crudo: exclusivamente para dibujo o trazado Pza 35 (restiradores), sin equipar.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.60.02
#      Texto crudo: Llamados "estaciones de trabajo", reconocibles como diseñados para alojar un sistema de
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.60.03
#      Texto crudo: computc > personal, con 'fen¡end0 por lo menos: — 25 una cubierta para monitor, una cubierta para teclado y una cubierta para la unidad central de proceso.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.60.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.70.03
#      Texto crudo: Muebles de plástico.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.82.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.83.01
#      Texto crudo: De ratán (roten).
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.89.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9403.99.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9404.10.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 7503.00.01
#      Texto crudo: Triciclos o cochecitos de pedal o palanca. Con ruedas, diseñados para que los conduzcan los niños, impulsados por ellos o por otra persona, E
# --> Procesando pag_0179.jpg (49 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.02
#      Texto crudo: o accionados por baterías recargables de hasta Pza 30 12 V, excepto, en ambos casos, lo comprendido en la fracción arancelaria 9503.00.01. x y Competitividad z LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE CÓDIGO DESCRIPCIÓN IMPUESTO DE IMPORTACIÓN ¡ Muñecas y muñecos que representen solamente * seres humanos, incluso vestidos, que contengan
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.04
#      Texto crudo: mecanismos operados eléctrica o 30 electrónicamente, excepto lo comprendido en la fracción arancelaria 9503.00.05. Muñecas y muñecos que representen solamente seres humanos, de longitud inferior o igual a 30
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.05
#      Texto crudo: em, incluso vestidos, articulados o con Pza 30 mecanismos operados eléctrica o electrónicamente.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.07
#      Texto crudo: Tre nes elec'mc< >s, mclu¡do s los carriles (rieles), Kg 30 señales y demás accesorios. Juguetes terapéutico-pedagógicos, reconocibles como diseñados exclusivamente '
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.08
#      Texto crudo: para usos cl¡n¡cos, para corregir dnsfunc10neg Kg 30 psicomotrices o problemas de lento aprendizaje, en instituciones de educación especial o similares.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.09
#      Texto crudo: Modelos reducidos "a escala" para ensamblar, Kg 30 de madera de balsa. Modelos reducidos "a escala" para ensamblar, incluso los que tengan componentes
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.10
#      Texto crudo: electrónicos o eléctricos, excepto lo Kg 30 comprendido en la fracción arancelaria
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.07
#      Texto crudo: .
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.11
#      Texto crudo: -Juegos o surtidos de cgnstrucc¡on: los demás Kg 30 juguetes de construcción.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.12
#      Texto crudo: Juguetes que representen animales o seres no ua 30 humanos, rellenos.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.13
#      Texto crudo: Juguetes que representen animales o seres no Kg 30 humanos, sin rellenar, de papel o cartón.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.15
#      Texto crudo: Instrumentos y aparatos, de música, de juguete.
# --> Procesando pag_0180.jpg (46 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.16
#      Texto crudo: Rompecabezas de papel o cartón. 1 y Competitividad - LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE CÓDIGO DESCRIPCIÓN IMPUESTO DE IMPORTACIÓN
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.17
#      Texto crudo: Rompecobezas de materias distintas a papel o cartón. Juegos o surtidos reconocibles como diseñados exclusivamente para que el niño o la niña, 92503.00.18 representen un personaje, profesión u oficio, Kg 30 excepto juegos que imiten preparaciones de belleza, de maquillaje o de manicura. Q Juguetes y modelos, con motor, excepto lo comprendido en las fracciones arancelarias 92503.00.20 9503.00.02, 9503.00.04, 9503.00.05, 9503.00.07, Kg 30 92503.00.09, 9503.00.10, 9503.00.11, 9503.00.12,
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.15
#      Texto crudo: y 9503.00.18.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.21
#      Texto crudo: Preparaciones de materias plásticas, o caucho,
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.22
#      Texto crudo: reconocibles como diseñadas para formar Kg 30 globos por insuflado. Juguetes inflables, incluso las pelotas de juguete
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.23
#      Texto crudo: fabricadas exc us¡vom ente de moter ugs plásticas, Kg 30 excepto lo comprendido en la fracción arancelaria 9503.00.22. Juguetes destinados a niños de hasta 36 meses de edad, excepto lo comprendido en las fracciones arancelarias ?503.00.01, 9503.00.02,
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.24
#      Texto crudo: 9593 90,04, 9503.00.05, 9503.00.11, 9503.00.12, Kg s 92503.00.13, 9503.00.15, 9503.00.16, 9503.00.17,
# --> Procesando pag_0181.jpg (47 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.20
#      Texto crudo: y 9503.00.23. Juguetes réplica de armas de fuego, que tengan apariencia, forma y/o configuración de las z 92503.00.25 armas de la subpartida 9301 .90, o de las partidas Kg 30 93.02 y 93.03, pero que no sean las armas comprendidas en la partida ?3.04. y Competitividad - LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE — l XVI LEGIS TURA m==s DESCRIPCIÓN ¡ IMPUESTO DE IMPORTACIÓN > Juguetes reconocibles como diseñados 1
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.26
#      Texto crudo: exclus¡vomente para Ionzgf agua, excepto los Kg 30 comprendidos en la fracción arancelaria
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.25
#      Texto crudo: . Prendas, complementos (accesorios) de vestir,
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.28
#      Texto crudo: colz odo, sombr eros y demás tocados, para Kg 30 muñecas y muñecos que representen solamente seres humanos. Partes, piezas y accesorios, reconocibles como ( diseñadas para coches y sillas de ruedas para
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.35
#      Texto crudo: muñecas o muñecos, para los demc¡s juguetes Kg 30 de rueda, o para lo comprendido en las fracciones arancelarias ?503.00.21, 9503.00.25 o
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.26
#      Texto crudo: . Los demás juguetes con ruedas diseñados para
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.91
#      Texto crudo: que los conduzcan los niños; coches y sillas de Pza 30 ruedas para muñecas o muñecos. Las demás muñecas y muñecos que representen
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.92
#      Texto crudo: solamente seres humo nos, incluso ves.hdos, Pza 30 excepto lo comprendido en las fracciones arancelarias 9503.00.04.y ?503.00.05.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 2503.00.93
#      Texto crudo: Los demás 1uguefes que representen animales o Kg 30 seres no humanos, sin rellenar.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9503.00.99
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9504.40.01
#      Texto crudo:
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9505.90.99
#      Texto crudo: Reconocibles como diseñadas exclusivamente
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 2613.90.01
#      Texto crudo: para los encendedores de cigarrillos a base de Kg 25 É resistencia para uso automotriz.
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 2619.00.01
#      Texto crudo: De pasta Qe papel, papel, guata de celulosa o Kg 35 napa de fibras de celulosa.
# --> Procesando pag_0182.jpg (31 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 9619.00.02
#      Texto crudo: De guata de materia textil. 1 y Competitividad A LA QUE SE REFORMAN DIVERSAS FRACCIONES ARANCELARIAS DE LA CAMARA DE TARIFA DE LA LEY DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE — L XV LEGISLATURA ua DESCRIPCIÓN IMPUESTO DE … IMPORTACIÓN Pañales y artículos similares, de otras materias 1
# --> Procesando pag_0183.jpg (35 líneas detectadas)
# --> Procesando pag_0184.jpg (32 líneas detectadas)
# --> Procesando pag_0185.jpg (31 líneas detectadas)
# --> Procesando pag_0186.jpg (32 líneas detectadas)
# --> Procesando pag_0187.jpg (29 líneas detectadas)
# --> Procesando pag_0188.jpg (23 líneas detectadas)
# --> Procesando pag_0189.jpg (1 líneas detectadas)
# --> Procesando pag_0190.jpg (29 líneas detectadas)
#   [ERROR DE FORMATO] No se pudo separar Unidad/Tasas para el código 7619.00.03
#      Texto crudo: textiles, excepto lo comprendido en la fracción Pza 35 arancelaria ?619.00.02. i TRANSITORIOS Primero. El presente Decreto entrará en vigor el primero de enero de 2026. Segundo. Las fracciones arancelarias de la Tarifa de la Ley de los Impuestos Generales de Importación y de Exportación y sus modificaciones, no previstas en el presente Decreto, seguirán vigentes en los términos en que fueron publicadas en el Diario Oficial de la Federación. Tercero. Se dejan sin efectos todas las disposiciones que se contrapongan a lo establecido en el presente Decreto. Comercio y Competitividad, en el Palacio Legislativo de San Lázaro, el 08 de diciembre de 2025. ) x / LISTA DE VOTACIÓN REUNIÓN EXTRAORDINARIA N*: 2 FECHA: 08/12/2025 DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE EXPORTACIÓN DIPUTADO G.P. SENTIDO DEL VOTO FAVOR CONTRA ABSTENCIÓN Salim Alle Miguel Ángel ¡ñ PAN l, ———— — ———————£E oo — — — EA AA A D Álvarez Nemer Mónica Angélica UN MORENA " i Z n s T ——D———————————— ——;—;— — ]]]——l— Armendáriz Guerra Carmen Patricia MORENA —l — 1 — ——————;[——————— Higareda Segura Lucero / k b¿ MORENA ) U -' >i¡ ;L¿ '/) s Z — A Z i Se — oe Dolt—o”— Morán Sánchez Leoncio Alfonso E 088 MORENA s ——————————;—]———— — —————————ll————lolDolENALN — Rodríguez Pérez Luz María ¿ MA p 4 e — A o I — T—]]];,;]” ;zUL]]Z;—;ZZZ;—ZZ—;—;Z—ZZZZ;Z;ZZZZ Valdés Peña Jesús W MORENA ) '. —————lo E l["¡IÓL Z EE — ———————————————[ —É DIRECCION GENERAL DE APOYO PARLAMENTARIO —————];cD—oÑ———————]—— ————— ———————————K]]——] — ————————————£——]] EN———1 ME llill ol l1o"¡jiL E A LISTA DE VOTACIÓN REUNIÓN EXTRAORDINARIA N”: 2 FECHA: 08/12/2025 DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE EXPORTACIÓN DIPUTADO G.P. SENTIDO DEL VOTO FAVOR CONTRA ABSTENCIÓN Castellanos Polanco Favio Ebrard Lestrade Sebastián JA MORENA º“-'. * Y a ——————————————l — 7 rO —]— — — D A o—ot—Uo— Escobar García Zenyazen Roberto V SA —l — E Z Z C R R R R R E e aR aa i G IDISIAAK ia — Ml d E González Soto Santiago — — a E— — López Gorosave Rocío w MORENA , r Miranda Barrera Luis Enrique Murguía Lardizábal Daniel CU MORENA , —l—o———lo — — S N ia£ — — ————L—Íaa] 2 DIRECCION GENERAL DE APOYO PARLAMENTARIO LISTA DE VOTACIÓN REUNIÓN EXTRAORDINARIA N”: 2 FECHA: 08/12/2025 DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE EXPORTACIÓN DIPUTADO G. P. SENTIDO DEL VOTO FAVOR CONTRA ABSTENCIÓN Vázquez Navarro Enrique ' M MORENA — A = E E — — ——o;—D—]] —£ ID Granados Trespalacios María Angélica : s a S Hiá c iaiiaaas — — A Sánchez Rodríguez Ernesto P— PAN Nl ': Y E r' .'. ..:J' , " — S Gali López José Antonio Scherer Pareyón Julio Javier —O PVEM Benavides Castañeda José Alberto i VA E S — — — S ——— M A Gutiérrez Arroyo Hugo Eduardo E AE -A s ————————————— — T DIRECCION GENERAL DE APOYO PARLAMENTARIO LISTA DE VOTACIÓN REUNIÓN EXTRAORDINARIA N": 2 FECHA: 08/12/2025 DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE EXPORTACIÓN DIPUTADO G.P. SENTIDO DEL VOTO FAVOR TRA ABSTENCIÓN Núñez Sánchez Gloria Elizabeth ) 1 NAA DI d - — — ————— A ZR Aguilar López José Alejandro — il 2d U E > :—¡ * a — DTTO A —— ON 20 al DI — EE Alonso Que Erubiel Lorenzo . . 7 Ávila Flores Claudia Selene " Q MORENA 5 Basto González Gabriela del Carmen S MORENA — ,'(¡). Blancas Mercado Bruno C ( U MORENA //JZ / Carvajal Hidalgo Alejandro /7 A MORENA f C o Mdan.limieaal Ie — — .—— A — — E— ——o—] DIRECCION GENERAL DE APOYO PARLAMENTARIO LISTA DE VOTACIÓN REUNIÓN EXTRAORDINARIA N": 2 FECHA: 08/12/2025 DE LOS IMPUESTOS GENERALES DE IMPORTACIÓN Y DE EXPORTACIÓN DIPUTADO G.P. SENTIDO DEL VOTO FAVOR CONTRA ABSTENCIÓN Nader Nasrallah Jesús Antonio C PAN ' —l —l;]—— — d A AA AN D — o————————[DI ool SD Pérez Popoca María Fabiola Karina ' MA MORENA C o a ¡——aa taáwas ea — ml "1E A ——— — —T[¡T—[——;]—]]——;—];;—;—;—;;;;— Torres Cofiño Marcelo de Jesús 3 y » — PAN A I EE AA 1d AA S DLAAEA — — — D7 TDTO oel Vacante (Por definir - PT) s ——————]]—]————— II DAO =. M — — — 2 D Valladares Eichelmann Juan Carlos ¿ q; PVEM Zamora Gastélum Mario DIRECCION GENERAL DE ...
#
# ========================================
# PROCESO TERMINADO. Datos guardados en: LIGIE_Base_Datos_Final.xlsx
# Registros extraídos: 2056
# Registros con error de formato: 2035
# ========================================

# %%
import cv2
import numpy as np
from PIL import Image
import pytesseract
import pandas as pd
import re
import os

# ==========================================
# CONFIGURACIÓN
# ==========================================
TESSERACT_CMD = r'C:/Program Files/Tesseract-OCR/tesseract.exe'
INPUT_FOLDER = "paginas_ligie_img"
OUTPUT_EXCEL = "LIGIE_Extraido_OCR_Columnas.xlsx"

pytesseract.pytesseract.tesseract_cmd = TESSERACT_CMD

# ==========================================
# 1. PREPROCESAMIENTO DE IMAGEN
# ==========================================

def preprocesar_imagen_tabla(img_path, debug=False):
    """
    Optimiza la imagen específicamente para tablas con líneas tenues
    """
    # Leer imagen
    img = cv2.imread(img_path)
    
    # Convertir a escala de grises
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Aumentar contraste agresivamente
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    contrast = clahe.apply(gray)
    
    # Binarización adaptativa (crucial para tablas con fondo gris)
    binary = cv2.adaptiveThreshold(
        contrast, 255,
        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY,
        15, 10
    )
    
    # Invertir si el fondo es oscuro
    if np.mean(binary) < 127:
        binary = cv2.bitwise_not(binary)
    
    # Eliminar ruido pequeño
    kernel = np.ones((2,2), np.uint8)
    cleaned = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
    
    # Guardar imagen debug si se solicita
    if debug:
        debug_path = img_path.replace('.jpg', '_debug.jpg')
        cv2.imwrite(debug_path, cleaned)
        print(f"  [DEBUG] Imagen procesada guardada en: {debug_path}")
    
    return Image.fromarray(cleaned)

# ==========================================
# 2. OCR CON COORDENADAS (CLAVE)
# ==========================================

def extraer_texto_con_coordenadas(img_path):
    """
    Usa pytesseract.image_to_data() para obtener coordenadas de cada palabra.
    Esto permite reconstruir columnas espacialmente.
    """
    img_prep = preprocesar_imagen_tabla(img_path)
    
    # Configuración optimizada para tablas
    custom_config = r'--oem 3 --psm 6 -c preserve_interword_spaces=1'
    
    # Extraer con coordenadas
    data = pytesseract.image_to_data(
        img_prep,
        lang='spa',
        config=custom_config,
        output_type=pytesseract.Output.DICT
    )
    
    return data

# ==========================================
# 3. RECONSTRUCCIÓN DE COLUMNAS
# ==========================================

def agrupar_por_filas(data, tolerancia_y=15):
    """
    Agrupa palabras que están en la misma línea horizontal (misma fila de tabla).
    tolerancia_y: píxeles de diferencia permitidos en el eje Y
    """
    palabras = []
    
    n_boxes = len(data['text'])
    for i in range(n_boxes):
        # Filtrar palabras vacías y con baja confianza
        if int(data['conf'][i]) > 30 and data['text'][i].strip():
            palabras.append({
                'texto': data['text'][i].strip(),
                'x': data['left'][i],
                'y': data['top'][i],
                'w': data['width'][i],
                'h': data['height'][i],
                'conf': data['conf'][i]
            })
    
    # Ordenar por posición vertical (Y)
    palabras.sort(key=lambda p: p['y'])
    
    # Agrupar en filas
    filas = []
    fila_actual = []
    y_ref = None
    
    for palabra in palabras:
        if y_ref is None:
            y_ref = palabra['y']
            fila_actual.append(palabra)
        elif abs(palabra['y'] - y_ref) <= tolerancia_y:
            # Misma fila
            fila_actual.append(palabra)
        else:
            # Nueva fila
            if fila_actual:
                filas.append(fila_actual)
            fila_actual = [palabra]
            y_ref = palabra['y']
    
    # Agregar última fila
    if fila_actual:
        filas.append(fila_actual)
    
    return filas

def detectar_columnas(filas):
    """
    Detecta las posiciones X de las columnas analizando múltiples filas.
    Retorna los rangos X de cada columna.
    """
    # Recolectar todas las posiciones X iniciales
    x_positions = []
    for fila in filas[:20]:  # Analizar primeras 20 filas
        for palabra in fila:
            x_positions.append(palabra['x'])
    
    # Clusterizar posiciones X (columnas típicas)
    x_positions.sort()
    
    columnas = []
    tolerancia_x = 50  # Píxeles de tolerancia horizontal
    
    for x in x_positions:
        # ¿Esta posición es una nueva columna o pertenece a una existente?
        agregado = False
        for col in columnas:
            if abs(x - col['x_inicio']) <= tolerancia_x:
                agregado = True
                break
        
        if not agregado:
            columnas.append({'x_inicio': x, 'x_fin': x + 200})  # Ancho estimado
    
    # Ordenar columnas de izquierda a derecha
    columnas.sort(key=lambda c: c['x_inicio'])
    
    # Ajustar límites finales
    for i in range(len(columnas) - 1):
        columnas[i]['x_fin'] = columnas[i+1]['x_inicio'] - 5
    
    return columnas

def asignar_palabras_a_columnas(fila, columnas):
    """
    Asigna cada palabra de una fila a su columna correspondiente.
    """
    celdas = [[] for _ in columnas]
    
    for palabra in fila:
        x_centro = palabra['x'] + palabra['w'] / 2
        
        for idx, col in enumerate(columnas):
            if col['x_inicio'] <= x_centro <= col['x_fin']:
                celdas[idx].append(palabra['texto'])
                break
    
    # Unir palabras dentro de cada celda
    return [' '.join(celda) for celda in celdas]

# ==========================================
# 4. VALIDACIÓN Y LIMPIEZA
# ==========================================

def validar_fila_arancelaria(fila_texto):
    """
    Valida que una fila extraída contenga un código arancelario válido.
    """
    if not fila_texto or len(fila_texto) < 3:
        return False
    
    codigo = fila_texto[0]
    
    # Regex para código arancelario
    if re.match(r'\d{4}\.\d{2}\.\d{2}', codigo):
        return True
    
    return False

def limpiar_descripcion(texto):
    """
    Limpia errores comunes del OCR en descripciones.
    """
    # Eliminar caracteres extraños
    texto = re.sub(r'[|_]', ' ', texto)
    texto = re.sub(r'\s+', ' ', texto).strip()
    
    # Asegurar punto final
    if texto and not texto.endswith('.'):
        texto += '.'
    
    return texto

# ==========================================
# 5. PROCESO PRINCIPAL
# ==========================================

def procesar_imagenes_con_columnas():
    """
    Proceso completo: lee imágenes, extrae con coordenadas, reconstruye tabla.
    """
    if not os.path.exists(INPUT_FOLDER):
        print(f"Error: No existe la carpeta {INPUT_FOLDER}")
        return
    
    archivos = sorted([f for f in os.listdir(INPUT_FOLDER) if f.endswith('.jpg')])
    
    registros_finales = []
    
    print(f"Iniciando extracción inteligente sobre {len(archivos)} imágenes...\n")
    
    for idx, archivo in enumerate(archivos, 1):
        img_path = os.path.join(INPUT_FOLDER, archivo)
        
        print(f"[{idx}/{len(archivos)}] Procesando: {archivo}")
        
        try:
            # 1. OCR con coordenadas
            data = extraer_texto_con_coordenadas(img_path)
            
            # 2. Agrupar en filas
            filas = agrupar_por_filas(data, tolerancia_y=15)
            
            if not filas:
                print(f"  ⚠️  No se detectó texto en la página")
                continue
            
            # 3. Detectar columnas (solo en primera página o cada 10 páginas)
            if idx == 1 or idx % 10 == 0:
                columnas = detectar_columnas(filas)
                print(f"  ✓ Detectadas {len(columnas)} columnas")
            
            # 4. Procesar cada fila
            for fila in filas:
                celdas = asignar_palabras_a_columnas(fila, columnas)
                
                # Validar que sea una fila de datos
                if validar_fila_arancelaria(celdas):
                    
                    registro = {
                        'CODIGO': celdas[0] if len(celdas) > 0 else '',
                        'DESCRIPCION': limpiar_descripcion(celdas[1]) if len(celdas) > 1 else '',
                        'UNIDAD': celdas[2] if len(celdas) > 2 else '',
                        'TASA_INICIATIVA': celdas[3] if len(celdas) > 3 else '',
                        'TASA_DICTAMEN': celdas[4] if len(celdas) > 4 else '',
                        'PAGINA': idx,
                        'ARCHIVO': archivo
                    }
                    
                    registros_finales.append(registro)
                    print(f"  ✓ {registro['CODIGO'][:15]}... | {registro['UNIDAD']}")
        
        except Exception as e:
            print(f"  ❌ Error en {archivo}: {str(e)}")
            continue
    
    # ==========================================
    # 6. EXPORTACIÓN
    # ==========================================
    
    if registros_finales:
        df = pd.DataFrame(registros_finales)
        
        # Estadísticas
        total = len(df)
        completos = len(df[df['DESCRIPCION'].str.len() > 10])
        
        df.to_excel(OUTPUT_EXCEL, index=False)
        
        print("\n" + "="*60)
        print(f"✅ EXTRACCIÓN COMPLETADA")
        print(f"📁 Archivo: {OUTPUT_EXCEL}")
        print(f"📊 Total registros: {total}")
        print(f"✓ Registros completos: {completos} ({completos/total*100:.1f}%)")
        print("="*60)
        
        # Mostrar muestra
        print("\n🔍 MUESTRA DE DATOS:")
        print(df.head(10).to_string())
        
    else:
        print("\n❌ No se extrajo ningún registro. Revisa las imágenes.")

if __name__ == "__main__":
    # Opción: Generar imagen debug de la primera página
    # preprocesar_imagen_tabla(os.path.join(INPUT_FOLDER, "pag_0001.jpg"), debug=True)
    
    procesar_imagenes_con_columnas()
# Out:
# Iniciando extracción inteligente sobre 190 imágenes...
#
# [1/190] Procesando: pag_0001.jpg
#   ✓ Detectadas 25 columnas
# [2/190] Procesando: pag_0002.jpg
# [3/190] Procesando: pag_0003.jpg
# [4/190] Procesando: pag_0004.jpg
# [5/190] Procesando: pag_0005.jpg
# [6/190] Procesando: pag_0006.jpg
# [7/190] Procesando: pag_0007.jpg
# [8/190] Procesando: pag_0008.jpg
# [9/190] Procesando: pag_0009.jpg
# [10/190] Procesando: pag_0010.jpg
#   ✓ Detectadas 28 columnas
# [11/190] Procesando: pag_0011.jpg
# [12/190] Procesando: pag_0012.jpg
# [13/190] Procesando: pag_0013.jpg
#   ⚠️  No se detectó texto en la página
# [14/190] Procesando: pag_0014.jpg
# [15/190] Procesando: pag_0015.jpg
# [16/190] Procesando: pag_0016.jpg
# [17/190] Procesando: pag_0017.jpg
# [18/190] Procesando: pag_0018.jpg
# [19/190] Procesando: pag_0019.jpg
# [20/190] Procesando: pag_0020.jpg
#   ✓ Detectadas 31 columnas
# [21/190] Procesando: pag_0021.jpg
# [22/190] Procesando: pag_0022.jpg
# [23/190] Procesando: pag_0023.jpg
# [24/190] Procesando: pag_0024.jpg
# [25/190] Procesando: pag_0025.jpg
# [26/190] Procesando: pag_0026.jpg
# [27/190] Procesando: pag_0027.jpg
# [28/190] Procesando: pag_0028.jpg
# [29/190] Procesando: pag_0029.jpg
# [30/190] Procesando: pag_0030.jpg
#   ✓ Detectadas 30 columnas
# [31/190] Procesando: pag_0031.jpg
# [32/190] Procesando: pag_0032.jpg
# [33/190] Procesando: pag_0033.jpg
# [34/190] Procesando: pag_0034.jpg
# [35/190] Procesando: pag_0035.jpg
# [36/190] Procesando: pag_0036.jpg
# [37/190] Procesando: pag_0037.jpg
# [38/190] Procesando: pag_0038.jpg
# [39/190] Procesando: pag_0039.jpg
# [40/190] Procesando: pag_0040.jpg
#   ✓ Detectadas 26 columnas
# [41/190] Procesando: pag_0041.jpg
# [42/190] Procesando: pag_0042.jpg
# [43/190] Procesando: pag_0043.jpg
# [44/190] Procesando: pag_0044.jpg
# [45/190] Procesando: pag_0045.jpg
# [46/190] Procesando: pag_0046.jpg
# [47/190] Procesando: pag_0047.jpg
# [48/190] Procesando: pag_0048.jpg
# [49/190] Procesando: pag_0049.jpg
# [50/190] Procesando: pag_0050.jpg
#   ✓ Detectadas 27 columnas
# [51/190] Procesando: pag_0051.jpg
# [52/190] Procesando: pag_0052.jpg
# [53/190] Procesando: pag_0053.jpg
# [54/190] Procesando: pag_0054.jpg
# [55/190] Procesando: pag_0055.jpg
# [56/190] Procesando: pag_0056.jpg
# [57/190] Procesando: pag_0057.jpg
# [58/190] Procesando: pag_0058.jpg
# [59/190] Procesando: pag_0059.jpg
# [60/190] Procesando: pag_0060.jpg
#   ✓ Detectadas 27 columnas
# [61/190] Procesando: pag_0061.jpg
# [62/190] Procesando: pag_0062.jpg
# [63/190] Procesando: pag_0063.jpg
# [64/190] Procesando: pag_0064.jpg
# [65/190] Procesando: pag_0065.jpg
# [66/190] Procesando: pag_0066.jpg
# [67/190] Procesando: pag_0067.jpg
# [68/190] Procesando: pag_0068.jpg
# [69/190] Procesando: pag_0069.jpg
# [70/190] Procesando: pag_0070.jpg
#   ✓ Detectadas 30 columnas
# [71/190] Procesando: pag_0071.jpg
# [72/190] Procesando: pag_0072.jpg
#   ⚠️  No se detectó texto en la página
# [73/190] Procesando: pag_0073.jpg
# [74/190] Procesando: pag_0074.jpg
# [75/190] Procesando: pag_0075.jpg
# [76/190] Procesando: pag_0076.jpg
# [77/190] Procesando: pag_0077.jpg
# [78/190] Procesando: pag_0078.jpg
# [79/190] Procesando: pag_0079.jpg
# [80/190] Procesando: pag_0080.jpg
#   ✓ Detectadas 27 columnas
# [81/190] Procesando: pag_0081.jpg
# [82/190] Procesando: pag_0082.jpg
# [83/190] Procesando: pag_0083.jpg
# [84/190] Procesando: pag_0084.jpg
# [85/190] Procesando: pag_0085.jpg
# [86/190] Procesando: pag_0086.jpg
# [87/190] Procesando: pag_0087.jpg
# [88/190] Procesando: pag_0088.jpg
# [89/190] Procesando: pag_0089.jpg
# [90/190] Procesando: pag_0090.jpg
#   ✓ Detectadas 24 columnas
# [91/190] Procesando: pag_0091.jpg
# [92/190] Procesando: pag_0092.jpg
# [93/190] Procesando: pag_0093.jpg
#   ⚠️  No se detectó texto en la página
# [94/190] Procesando: pag_0094.jpg
# [95/190] Procesando: pag_0095.jpg
# [96/190] Procesando: pag_0096.jpg
# [97/190] Procesando: pag_0097.jpg
# [98/190] Procesando: pag_0098.jpg
# [99/190] Procesando: pag_0099.jpg
# [100/190] Procesando: pag_0100.jpg
#   ✓ Detectadas 26 columnas
# [101/190] Procesando: pag_0101.jpg
# [102/190] Procesando: pag_0102.jpg
# [103/190] Procesando: pag_0103.jpg
# [104/190] Procesando: pag_0104.jpg
# [105/190] Procesando: pag_0105.jpg
# [106/190] Procesando: pag_0106.jpg
# [107/190] Procesando: pag_0107.jpg
# [108/190] Procesando: pag_0108.jpg
# [109/190] Procesando: pag_0109.jpg
# [110/190] Procesando: pag_0110.jpg
#   ✓ Detectadas 29 columnas
# [111/190] Procesando: pag_0111.jpg
# [112/190] Procesando: pag_0112.jpg
# [113/190] Procesando: pag_0113.jpg
# [114/190] Procesando: pag_0114.jpg
# [115/190] Procesando: pag_0115.jpg
# [116/190] Procesando: pag_0116.jpg
# [117/190] Procesando: pag_0117.jpg
# [118/190] Procesando: pag_0118.jpg
# [119/190] Procesando: pag_0119.jpg
# [120/190] Procesando: pag_0120.jpg
#   ✓ Detectadas 29 columnas
# [121/190] Procesando: pag_0121.jpg
# [122/190] Procesando: pag_0122.jpg
# [123/190] Procesando: pag_0123.jpg
# [124/190] Procesando: pag_0124.jpg
# [125/190] Procesando: pag_0125.jpg
# [126/190] Procesando: pag_0126.jpg
# [127/190] Procesando: pag_0127.jpg
# [128/190] Procesando: pag_0128.jpg
# [129/190] Procesando: pag_0129.jpg
# [130/190] Procesando: pag_0130.jpg
#   ✓ Detectadas 26 columnas
# [131/190] Procesando: pag_0131.jpg
# [132/190] Procesando: pag_0132.jpg
# [133/190] Procesando: pag_0133.jpg
# [134/190] Procesando: pag_0134.jpg
# [135/190] Procesando: pag_0135.jpg
# [136/190] Procesando: pag_0136.jpg
# [137/190] Procesando: pag_0137.jpg
# [138/190] Procesando: pag_0138.jpg
# [139/190] Procesando: pag_0139.jpg
# [140/190] Procesando: pag_0140.jpg
#   ✓ Detectadas 25 columnas
# [141/190] Procesando: pag_0141.jpg
# [142/190] Procesando: pag_0142.jpg
# [143/190] Procesando: pag_0143.jpg
# [144/190] Procesando: pag_0144.jpg
# [145/190] Procesando: pag_0145.jpg
# [146/190] Procesando: pag_0146.jpg
# [147/190] Procesando: pag_0147.jpg
# [148/190] Procesando: pag_0148.jpg
# [149/190] Procesando: pag_0149.jpg
# [150/190] Procesando: pag_0150.jpg
#   ✓ Detectadas 26 columnas
# [151/190] Procesando: pag_0151.jpg
# [152/190] Procesando: pag_0152.jpg
# [153/190] Procesando: pag_0153.jpg
# [154/190] Procesando: pag_0154.jpg
# [155/190] Procesando: pag_0155.jpg
# [156/190] Procesando: pag_0156.jpg
# [157/190] Procesando: pag_0157.jpg
# [158/190] Procesando: pag_0158.jpg
# [159/190] Procesando: pag_0159.jpg
# [160/190] Procesando: pag_0160.jpg
#   ✓ Detectadas 26 columnas
# [161/190] Procesando: pag_0161.jpg
# [162/190] Procesando: pag_0162.jpg
# [163/190] Procesando: pag_0163.jpg
# [164/190] Procesando: pag_0164.jpg
# [165/190] Procesando: pag_0165.jpg
# [166/190] Procesando: pag_0166.jpg
# [167/190] Procesando: pag_0167.jpg
# [168/190] Procesando: pag_0168.jpg
# [169/190] Procesando: pag_0169.jpg
# [170/190] Procesando: pag_0170.jpg
#   ✓ Detectadas 25 columnas
# [171/190] Procesando: pag_0171.jpg
# [172/190] Procesando: pag_0172.jpg
# [173/190] Procesando: pag_0173.jpg
# [174/190] Procesando: pag_0174.jpg
# [175/190] Procesando: pag_0175.jpg
# [176/190] Procesando: pag_0176.jpg
# [177/190] Procesando: pag_0177.jpg
# [178/190] Procesando: pag_0178.jpg
# [179/190] Procesando: pag_0179.jpg
# [180/190] Procesando: pag_0180.jpg
#   ✓ Detectadas 26 columnas
# [181/190] Procesando: pag_0181.jpg
# [182/190] Procesando: pag_0182.jpg
# [183/190] Procesando: pag_0183.jpg
# [184/190] Procesando: pag_0184.jpg
# [185/190] Procesando: pag_0185.jpg
# [186/190] Procesando: pag_0186.jpg
# [187/190] Procesando: pag_0187.jpg
# [188/190] Procesando: pag_0188.jpg
# [189/190] Procesando: pag_0189.jpg
#   ⚠️  No se detectó texto en la página
# [190/190] Procesando: pag_0190.jpg
#   ✓ Detectadas 32 columnas
#
# ❌ No se extrajo ningún registro. Revisa las imágenes.

# %%
pip install img2table --user
# Out:
# Collecting img2table
#   Using cached img2table-1.4.2-py3-none-any.whl.metadata (21 kB)
# Collecting polars>=1.2 (from polars[pandas]>=1.2->img2table)
#   Using cached polars-1.36.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyarrow>=7 in c:\users\edward\miniconda3\lib\site-packages (from img2table) (22.0.0)
# Requirement already satisfied: numpy in c:\users\edward\miniconda3\lib\site-packages (from img2table) (2.2.6)
# Requirement already satisfied: pypdfium2==4.30.0 in c:\users\edward\miniconda3\lib\site-packages (from img2table) (4.30.0)
# Collecting opencv-contrib-python-headless>=4 (from img2table)
#   Using cached opencv_contrib_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numba (from img2table)
#   Using cached numba-0.63.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Collecting beautifulsoup4 (from img2table)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: xlsxwriter>=3.0.6 in c:\users\edward\miniconda3\lib\site-packages (from img2table) (3.2.9)
# Requirement already satisfied: polars-runtime-32==1.36.0 in c:\users\edward\miniconda3\lib\site-packages (from polars>=1.2->polars[pandas]>=1.2->img2table) (1.36.0)
# Requirement already satisfied: pandas in c:\users\edward\miniconda3\lib\site-packages (from polars[pandas]>=1.2->img2table) (2.3.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\edward\miniconda3\lib\site-packages (from beautifulsoup4->img2table) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\edward\miniconda3\lib\site-packages (from beautifulsoup4->img2table) (4.12.2)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba->img2table)
#   Using cached llvmlite-0.46.0-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edward\miniconda3\lib\site-packages (from pandas->polars[pandas]>=1.2->img2table) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edward\miniconda3\lib\site-packages (from pandas->polars[pandas]>=1.2->img2table) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edward\miniconda3\lib\site-packages (from pandas->polars[pandas]>=1.2->img2table) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\edward\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->polars[pandas]>=1.2->img2table) (1.17.0)
# Using cached img2table-1.4.2-py3-none-any.whl (91 kB)
# Using cached opencv_contrib_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl (45.2 MB)
# Using cached polars-1.36.0-py3-none-any.whl (801 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached numba-0.63.0-cp313-cp313-win_amd64.whl (2.8 MB)
# Using cached llvmlite-0.46.0-cp313-cp313-win_amd64.whl (38.1 MB)
# Installing collected packages: polars, opencv-contrib-python-headless, llvmlite, beautifulsoup4, numba, img2table
#
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ---------------------------------------- 0/6 [polars]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------ -------------------------------- 1/6 [opencv-contrib-python-headless]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    ------------- -------------------------- 2/6 [llvmlite]
#    -------------------- ------------------- 3/6 [beautifulsoup4]
#    -------------------- ------------------- 3/6 [beautifulsoup4]
#    -------------------- ------------------- 3/6 [beautifulsoup4]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    -------------------------- ------------- 4/6 [numba]
#    --------------------------------- ------ 5/6 [img2table]
#    --------------------------------- ------ 5/6 [img2table]
#    --------------------------------- ------ 5/6 [img2table]
#    --------------------------------- ------ 5/6 [img2table]
#    --------------------------------- ------ 5/6 [img2table]
#    --------------------------------- ------ 5/6 [img2table]
#    ---------------------------------------- 6/6 [img2table]
#
# Successfully installed beautifulsoup4-4.14.3 img2table-1.4.2 llvmlite-0.46.0 numba-0.63.0 opencv-contrib-python-headless-4.12.0.88 polars-1.36.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from img2table.document import PDF
from img2table.ocr import TesseractOCR
import os
import re

# ==========================================
# 1. CONFIGURACIÓN DE RUTAS
# ==========================================
# Ajusta estas rutas a tu entorno local
RUTA_TESSERACT = r"C:/Program Files/Tesseract-OCR"
ARCHIVO_PDF = r"C:/Users/Edward/Downloads/20251209-V-30-109.pdf"
ARCHIVO_SALIDA = "tablas_extraidas_corregido.xlsx"

# Nombres estándar para las columnas (para evitar desfases)
COLUMNAS_ESTANDAR = [
    "CÓDIGO", 
    "DESCRIPCIÓN", 
    "UNIDAD", 
    "CUOTA_INICIATIVA", 
    "CUOTA_DICTAMEN"
]

# ==========================================
# 2. FUNCIONES DE LIMPIEZA
# ==========================================

def configurar_entorno():
    if os.path.exists(RUTA_TESSERACT):
        os.environ["PATH"] += os.pathsep + RUTA_TESSERACT
        return True
    else:
        print(f"❌ ERROR: No se encuentra Tesseract en: {RUTA_TESSERACT}")
        return False

def limpiar_texto(val):
    """Limpia saltos de línea y espacios extra."""
    if pd.isna(val):
        return val
    return str(val).replace('\n', ' ').strip()

def intentar_separar_cuotas(row):
    """
    Si la columna de Dictamen está vacía pero la de Iniciativa tiene dos números
    (ej: '35 25'), intenta separarlos.
    """
    iniciativa = str(row['CUOTA_INICIATIVA']).strip()
    dictamen = str(row['CUOTA_DICTAMEN']).strip()
    
    # Si dictamen está vacío (o es nan/None) y la iniciativa parece tener dos valores
    if (dictamen == 'nan' or dictamen == 'None' or dictamen == '') and ' ' in iniciativa:
        partes = iniciativa.split()
        # Verificamos si parece que son dos números (ej. '10 7' o '35 25')
        if len(partes) >= 2:
            # Asumimos que el último valor es el dictamen
            nuevo_dictamen = partes[-1]
            nueva_iniciativa = " ".join(partes[:-1])
            return nueva_iniciativa, nuevo_dictamen
            
    return row['CUOTA_INICIATIVA'], row['CUOTA_DICTAMEN']

def estandarizar_tabla(df, num_pagina):
    """
    Limpia y estandariza una tabla individual antes de concatenarla.
    """
    # 1. Eliminar filas vacías
    df = df.dropna(how='all')
    
    # 2. Eliminar columnas que sean totalmente vacías (bordes fantasma)
    df = df.dropna(axis=1, how='all')
    
    # 3. Normalizar a 5 columnas
    # Si hay más de 5, conservamos las 5 primeras (asumiendo orden izquierda-derecha)
    # Si hay menos, añadimos vacías.
    columnas_actuales = df.shape[1]
    
    if columnas_actuales > 5:
        # A veces crea columnas extra al final vacías o con basura
        df = df.iloc[:, :5]
    elif columnas_actuales < 5:
        # Rellenar con columnas vacías hasta llegar a 5
        for _ in range(5 - columnas_actuales):
            df[len(df.columns)] = None

    # 4. Asignar nombres estándar
    df.columns = COLUMNAS_ESTANDAR
    
    # 5. Detectar y eliminar fila de encabezado si existe en los datos
    # Buscamos si la primera fila contiene "CÓDIGO" o "DESCRIPCIÓN"
    if not df.empty:
        fila_0 = " ".join([str(x).upper() for x in df.iloc[0].values])
        if "CÓDIGO" in fila_0 or "DESCRIPCIÓN" in fila_0:
            df = df.iloc[1:] # Eliminar primera fila
    
    # 6. Añadir metadato de página
    df['Pagina_Origen'] = num_pagina + 1
    
    return df

# ==========================================
# 3. EXTRACCIÓN PRINCIPAL
# ==========================================

def extraer_tablas(ruta_pdf):
    try:
        ocr = TesseractOCR(n_threads=1, lang="spa")
    except Exception as e:
        print(f"❌ Error OCR: {e}")
        return None

    print(f"🔄 Leyendo PDF: {ruta_pdf}...")
    doc = PDF(src=ruta_pdf)

    print("⏳ Ejecutando OCR (esto puede tardar)...")
    try:
        # borderless_tables=False para usar las líneas de la tabla
        tablas_extraidas = doc.extract_tables(ocr=ocr,
                                              implicit_rows=False,
                                              borderless_tables=False,
                                              min_confidence=50)
    except Exception as e:
        print(f"❌ Error extrayendo tablas: {e}")
        return None

    lista_dfs = []

    for numero_pagina, tablas in tablas_extraidas.items():
        for tabla in tablas:
            df = tabla.df
            
            # Procesar la tabla individualmente
            df_limpio = estandarizar_tabla(df, numero_pagina)
            
            # Solo añadir si tiene datos
            if not df_limpio.empty:
                lista_dfs.append(df_limpio)

    if lista_dfs:
        print(f"✅ Se encontraron {len(lista_dfs)} tablas. Concatenando...")
        
        # Concatenación segura (ahora todos tienen las mismas columnas)
        df_final = pd.concat(lista_dfs, ignore_index=True)
        
        # ==========================================
        # 4. LIMPIEZA POST-CONCATENACIÓN
        # ==========================================
        
        # A. Limpieza de texto general
        for col in COLUMNAS_ESTANDAR:
            df_final[col] = df_final[col].apply(limpiar_texto)
            
        # B. Eliminar filas que sean encabezados repetidos (basura residual)
        # Filtramos filas donde la columna CÓDIGO diga literalmente "CÓDIGO" o similar
        filtro_basura = df_final['CÓDIGO'].str.upper().str.contains("CÓDIGO|DESCRIPCIÓN", na=False)
        df_final = df_final[~filtro_basura]
        
        # C. Eliminar filas donde el CÓDIGO sea demasiado corto (ruido OCR)
        df_final = df_final[df_final['CÓDIGO'].str.len() > 3]
        
        # D. Corregir "Huecos" en las cuotas (Separar valores fusionados)
        # Aplica la lógica fila por fila
        df_final[['CUOTA_INICIATIVA', 'CUOTA_DICTAMEN']] = df_final.apply(
            lambda x: pd.Series(intentar_separar_cuotas(x)), axis=1
        )

        return df_final
    else:
        return None

# ==========================================
# 4. EJECUCIÓN
# ==========================================

if __name__ == "__main__":
    if configurar_entorno():
        if os.path.exists(ARCHIVO_PDF):
            df_resultado = extraer_tablas(ARCHIVO_PDF)
            
            if df_resultado is not None and not df_resultado.empty:
                try:
                    df_resultado.to_excel(ARCHIVO_SALIDA, index=False)
                    print(f"🎉 ¡ÉXITO! Archivo guardado: {ARCHIVO_SALIDA}")
                    print(df_resultado.head())
                    print(f"\nTotal de filas extraídas: {len(df_resultado)}")
                except PermissionError:
                    print(f"❌ ERROR: Cierra el archivo Excel '{ARCHIVO_SALIDA}' antes de correr el código.")
            else:
                print("⚠️ No se pudo extraer información válida.")
        else:
            print(f"❌ No encuentro el archivo: {ARCHIVO_PDF}")
# Out:
# 🔄 Leyendo PDF: C:/Users/Edward/Downloads/20251209-V-30-109.pdf...
# ⏳ Ejecutando OCR (esto puede tardar)...
# ✅ Se encontraron 78 tablas. Concatenando...
# 🎉 ¡ÉXITO! Archivo guardado: tablas_extraidas_corregido.xlsx
#        CÓDIGO                                     DESCRIPCIÓN UNIDAD  \
# 1  3303.00.01                               Aguas de tocador.   None
# 2  3303.00.99                                      Los demás.   None
# 3   3304.10.0  Preparaciones para el maquillaje de os labios.     Kg
# 4   3304.20.0   Preparaciones para el maquillaje de los ojos.     Kg
# 5   3304.30.0       Preparaciones para manicuras o pedicuros.     Kg
#
#   CUOTA_INICIATIVA CUOTA_DICTAMEN  Pagina_Origen
# 1               35             25              1
# 2               35             25              1
# 3               50             36              1
# 4               35             25              1
# 5               35             25              1
#
# Total de filas extraídas: 1438

# %%
pip install pdf2image pytesseract opencv-python pandas pillow numpy
# Out:
# Requirement already satisfied: pdf2image in c:\users\edward\miniconda3\lib\site-packages (1.17.0)
# Requirement already satisfied: pytesseract in c:\users\edward\miniconda3\lib\site-packages (0.3.13)
# Requirement already satisfied: opencv-python in c:\users\edward\miniconda3\lib\site-packages (4.12.0.88)
# Requirement already satisfied: pandas in c:\users\edward\miniconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: pillow in c:\users\edward\miniconda3\lib\site-packages (12.0.0)
# Requirement already satisfied: numpy in c:\users\edward\miniconda3\lib\site-packages (2.2.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\edward\miniconda3\lib\site-packages (from pytesseract) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edward\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edward\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edward\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\edward\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Extractor de tablas desde PDF con imágenes usando OCR
Requiere: pip install PyMuPDF pytesseract opencv-python pandas pillow numpy
También necesitas instalar Tesseract OCR en tu sistema:
- Windows: https://github.com/UB-Mannheim/tesseract/wiki
- Linux: sudo apt-get install tesseract-ocr tesseract-ocr-spa
- Mac: brew install tesseract tesseract-lang
"""

import cv2
import numpy as np
import pytesseract
import fitz  # PyMuPDF
from PIL import Image
import pandas as pd
import re
import os

# ============================================================================
# CONFIGURACIÓN DE RUTAS - Ajusta según tu instalación
# ============================================================================

# Ruta de Tesseract OCR (necesario para el OCR)
# Descomenta y ajusta según tu instalación:
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

# Ruta de Poppler (opcional, solo si usas pdf2image en lugar de PyMuPDF)
# Ejemplo: POPPLER_PATH = r'C:\poppler-24.08.0\Library\bin'
POPPLER_PATH = r'C:/Program Files/Poppler/poppler-25.12.0/Library/bin'

# ============================================================================

class PDFTableExtractor:
    def __init__(self, pdf_path, idioma='spa', usar_pymupdf=True):
        """
        Inicializa el extractor de tablas
        
        Args:
            pdf_path: Ruta al archivo PDF
            idioma: Idioma para OCR ('spa' para español, 'eng' para inglés)
            usar_pymupdf: Si True usa PyMuPDF, si False usa pdf2image+Poppler
        """
        self.pdf_path = pdf_path
        self.idioma = idioma
        self.usar_pymupdf = usar_pymupdf
        self.doc = None
        self.images = None
        
    def abrir_pdf(self):
        """Abre el documento PDF"""
        if not os.path.exists(self.pdf_path):
            raise FileNotFoundError(f"No se encuentra el archivo: {self.pdf_path}")
        
        if self.usar_pymupdf:
            self.doc = fitz.open(self.pdf_path)
            print(f"PDF abierto con PyMuPDF: {len(self.doc)} páginas")
        else:
            # Usar pdf2image con Poppler
            from pdf2image import convert_from_path
            print(f"Convirtiendo PDF con Poppler...")
            self.images = convert_from_path(
                self.pdf_path, 
                dpi=300,
                poppler_path=POPPLER_PATH
            )
            print(f"PDF convertido: {len(self.images)} páginas")
        
        return self.doc if self.usar_pymupdf else self.images
    
    def convertir_pagina_a_imagen(self, num_pagina, zoom=3.0):
        """Convierte una página del PDF a imagen de alta resolución"""
        if self.usar_pymupdf:
            # Usar PyMuPDF
            pagina = self.doc[num_pagina]
            
            # Matriz de transformación para aumentar resolución
            mat = fitz.Matrix(zoom, zoom)
            pix = pagina.get_pixmap(matrix=mat)
            
            # Convertir a formato numpy array
            img_data = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.h, pix.w, pix.n)
            
            # Si tiene canal alpha, convertir a RGB
            if pix.n == 4:
                img_data = cv2.cvtColor(img_data, cv2.COLOR_RGBA2RGB)
            
            return img_data
        else:
            # Usar pdf2image (ya convertido en abrir_pdf)
            if self.images is None:
                self.abrir_pdf()
            
            # Convertir PIL Image a numpy array
            img_pil = self.images[num_pagina]
            img_data = np.array(img_pil)
            
            # Asegurar que está en RGB
            if len(img_data.shape) == 2:
                img_data = cv2.cvtColor(img_data, cv2.COLOR_GRAY2RGB)
            elif img_data.shape[2] == 4:
                img_data = cv2.cvtColor(img_data, cv2.COLOR_RGBA2RGB)
            
            return img_data
    
    def preprocesar_imagen(self, imagen):
        """Mejora la imagen para mejor OCR"""
        # Convertir a escala de grises
        if len(imagen.shape) == 3:
            gray = cv2.cvtColor(imagen, cv2.COLOR_RGB2GRAY)
        else:
            gray = imagen
        
        # Aplicar umbralización adaptativa
        thresh = cv2.adaptiveThreshold(
            gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
            cv2.THRESH_BINARY, 11, 2
        )
        
        # Reducir ruido
        denoised = cv2.fastNlMeansDenoising(thresh, None, 10, 7, 21)
        
        # Opcional: dilatar ligeramente para unir texto fragmentado
        kernel = np.ones((1, 1), np.uint8)
        dilated = cv2.dilate(denoised, kernel, iterations=1)
        
        return dilated
    
    def detectar_tablas(self, imagen_procesada):
        """Detecta las regiones de tablas en la imagen"""
        # Detectar líneas horizontales y verticales
        horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (40, 1))
        vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 40))
        
        horizontal_lines = cv2.morphologyEx(imagen_procesada, cv2.MORPH_OPEN, horizontal_kernel)
        vertical_lines = cv2.morphologyEx(imagen_procesada, cv2.MORPH_OPEN, vertical_kernel)
        
        # Combinar líneas
        table_structure = cv2.addWeighted(horizontal_lines, 0.5, vertical_lines, 0.5, 0.0)
        
        # Encontrar contornos (tablas)
        contours, _ = cv2.findContours(table_structure, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        # Filtrar contornos por área mínima
        table_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > 5000]
        
        # Ordenar contornos de arriba hacia abajo
        table_contours = sorted(table_contours, key=lambda cnt: cv2.boundingRect(cnt)[1])
        
        return table_contours
    
    def extraer_texto_ocr(self, imagen, config_personalizado=''):
        """Extrae texto usando Tesseract OCR"""
        config_ocr = f'--oem 3 --psm 6 -l {self.idioma} {config_personalizado}'
        
        # Convertir numpy array a PIL Image si es necesario
        if isinstance(imagen, np.ndarray):
            imagen = Image.fromarray(imagen)
        
        texto = pytesseract.image_to_string(imagen, config=config_ocr)
        return texto
    
    def extraer_datos_estructurados(self, imagen, region=None):
        """Extrae datos de tabla usando OCR con detección de estructura"""
        if region is not None:
            x, y, w, h = region
            imagen_recortada = imagen[y:y+h, x:x+w]
        else:
            imagen_recortada = imagen
        
        # Convertir a PIL Image
        if isinstance(imagen_recortada, np.ndarray):
            pil_img = Image.fromarray(imagen_recortada)
        else:
            pil_img = imagen_recortada
        
        # Obtener datos con información de posición
        datos_ocr = pytesseract.image_to_data(
            pil_img, 
            lang=self.idioma,
            output_type=pytesseract.Output.DICT
        )
        
        # Organizar texto por líneas basándose en coordenadas Y
        lineas = {}
        for i, texto in enumerate(datos_ocr['text']):
            if texto.strip():
                conf = int(datos_ocr['conf'][i])
                if conf > 20:  # Filtrar baja confianza
                    y_pos = datos_ocr['top'][i]
                    x_pos = datos_ocr['left'][i]
                    
                    # Agrupar por línea (tolerancia de 15 píxeles)
                    linea_encontrada = False
                    for linea_y in lineas.keys():
                        if abs(y_pos - linea_y) < 15:
                            lineas[linea_y].append((x_pos, texto))
                            linea_encontrada = True
                            break
                    
                    if not linea_encontrada:
                        lineas[y_pos] = [(x_pos, texto)]
        
        # Ordenar líneas por posición Y y luego por X
        filas = []
        for y_pos in sorted(lineas.keys()):
            elementos_ordenados = sorted(lineas[y_pos], key=lambda x: x[0])
            fila = ' '.join([elem[1] for elem in elementos_ordenados])
            filas.append(fila)
        
        return filas
    
    def parsear_a_dataframe(self, filas):
        """Convierte las filas extraídas en un DataFrame"""
        if not filas:
            return pd.DataFrame()
        
        # Intentar detectar el encabezado (primera fila no vacía)
        datos = []
        encabezado = None
        
        for fila in filas:
            if fila.strip():
                # Dividir por múltiples espacios (2 o más)
                columnas = re.split(r'\s{2,}', fila.strip())
                if encabezado is None:
                    encabezado = columnas
                else:
                    datos.append(columnas)
        
        if encabezado and datos:
            # Asegurar que todas las filas tengan el mismo número de columnas
            max_cols = max(len(encabezado), max(len(fila) for fila in datos) if datos else 0)
            
            # Rellenar con vacíos si es necesario
            encabezado.extend([''] * (max_cols - len(encabezado)))
            for fila in datos:
                fila.extend([''] * (max_cols - len(fila)))
            
            # Crear DataFrame
            num_cols = len(datos[0]) if datos else len(encabezado)
            df = pd.DataFrame(datos, columns=encabezado[:num_cols])
            return df
        
        return pd.DataFrame()
    
    def procesar_pdf_completo(self, guardar_imagenes=False, zoom=3.0):
        """Procesa todo el PDF y extrae todas las tablas"""
        if self.usar_pymupdf:
            if self.doc is None:
                self.abrir_pdf()
            num_paginas = len(self.doc)
        else:
            if self.images is None:
                self.abrir_pdf()
            num_paginas = len(self.images)
        
        todas_las_tablas = []
        
        for num_pagina in range(num_paginas):
            print(f"\n{'='*60}")
            print(f"Procesando página {num_pagina + 1} de {num_paginas}...")
            print('='*60)
            
            # Convertir página a imagen
            imagen = self.convertir_pagina_a_imagen(num_pagina, zoom=zoom)
            
            # Preprocesar imagen
            img_procesada = self.preprocesar_imagen(imagen)
            
            if guardar_imagenes:
                cv2.imwrite(f'pagina_{num_pagina+1}_original.png', imagen)
                cv2.imwrite(f'pagina_{num_pagina+1}_procesada.png', img_procesada)
                print(f"✓ Imágenes guardadas")
            
            # Detectar tablas
            contornos_tablas = self.detectar_tablas(img_procesada)
            
            if contornos_tablas:
                print(f"✓ Se encontraron {len(contornos_tablas)} tabla(s)")
                
                for i, contorno in enumerate(contornos_tablas):
                    x, y, w, h = cv2.boundingRect(contorno)
                    print(f"\n  → Extrayendo tabla {i+1} (posición: x={x}, y={y}, w={w}, h={h})...")
                    
                    # Extraer datos de esta región
                    filas = self.extraer_datos_estructurados(img_procesada, (x, y, w, h))
                    
                    print(f"    • Filas detectadas: {len(filas)}")
                    
                    if filas:
                        df = self.parsear_a_dataframe(filas)
                        if not df.empty:
                            print(f"    • DataFrame creado: {df.shape[0]} filas x {df.shape[1]} columnas")
                            todas_las_tablas.append({
                                'pagina': num_pagina + 1,
                                'tabla': i + 1,
                                'dataframe': df,
                                'region': (x, y, w, h)
                            })
                        else:
                            print(f"    ⚠ No se pudo crear DataFrame")
            else:
                # Si no se detectan tablas, extraer todo el texto de la página
                print("⚠ No se detectaron tablas estructuradas, extrayendo todo el texto...")
                filas = self.extraer_datos_estructurados(img_procesada)
                
                print(f"  • Filas detectadas: {len(filas)}")
                
                if filas:
                    df = self.parsear_a_dataframe(filas)
                    if not df.empty:
                        print(f"  • DataFrame creado: {df.shape[0]} filas x {df.shape[1]} columnas")
                        todas_las_tablas.append({
                            'pagina': num_pagina + 1,
                            'tabla': 1,
                            'dataframe': df,
                            'region': None
                        })
        
        return todas_las_tablas
    
    def cerrar(self):
        """Cierra el documento PDF"""
        if self.doc:
            self.doc.close()

# Ejemplo de uso
if __name__ == "__main__":
    print("="*60)
    print("EXTRACTOR DE TABLAS PDF CON OCR")
    print("="*60)
    
    # Verificar que Tesseract está instalado
    try:
        version = pytesseract.get_tesseract_version()
        print(f"\n✓ Tesseract versión: {version}")
    except Exception as e:
        print(f"\n✗ ERROR: Tesseract no está instalado o no está en PATH")
        print(f"  Instala desde: https://github.com/UB-Mannheim/tesseract/wiki")
        print(f"  Detalle: {e}")
        exit(1)
    
    # Ruta del PDF
    pdf_path = r'C:/Users/Edward/Downloads/20251209-V-31-33.pdf'
    
    if not os.path.exists(pdf_path):
        print(f"\n✗ ERROR: No se encuentra el archivo {pdf_path}")
        exit(1)
    
    print(f"\n✓ Archivo encontrado: {pdf_path}")
    
    # Elegir método de conversión
    print("\n¿Qué método deseas usar para convertir el PDF?")
    print("1. PyMuPDF (recomendado, más rápido, no requiere Poppler)")
    print("2. pdf2image + Poppler (alternativo)")
    
    usar_pymupdf = True  # Cambiar a False para usar pdf2image+Poppler
    metodo = "PyMuPDF" if usar_pymupdf else "pdf2image+Poppler"
    print(f"\n✓ Usando método: {metodo}")
    
    # Inicializar extractor
    extractor = PDFTableExtractor(pdf_path, idioma='spa', usar_pymupdf=usar_pymupdf)
    
    try:
        # Procesar PDF (zoom más alto = mejor calidad pero más lento)
        tablas = extractor.procesar_pdf_completo(guardar_imagenes=True, zoom=3.0)
        
        # Mostrar y guardar resultados
        print(f"\n{'='*60}")
        print(f"RESULTADOS FINALES")
        print('='*60)
        print(f"\n✓ Total de tablas extraídas: {len(tablas)}\n")
        
        for tabla_info in tablas:
            print(f"\n{'─'*60}")
            print(f"Página {tabla_info['pagina']}, Tabla {tabla_info['tabla']}")
            print('─'*60)
            print(tabla_info['dataframe'])
            print(f"\nDimensiones: {tabla_info['dataframe'].shape[0]} filas x {tabla_info['dataframe'].shape[1]} columnas")
            
            # Guardar a CSV
            nombre_archivo = f"tabla_p{tabla_info['pagina']}_t{tabla_info['tabla']}.csv"
            tabla_info['dataframe'].to_csv(nombre_archivo, index=False, encoding='utf-8-sig')
            print(f"✓ Guardado en: {nombre_archivo}")
        
        print(f"\n{'='*60}")
        print("PROCESO COMPLETADO")
        print('='*60)
        
    except Exception as e:
        print(f"\n✗ ERROR durante el procesamiento: {e}")
        import traceback
        traceback.print_exc()
    
    finally:
        extractor.cerrar()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 13
#      11 import numpy as np
#      12 import pytesseract
# ---> 13 import fitz  # PyMuPDF
#      14 from PIL import Image
#      15 import pandas as pd
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\frontend\__init__.py:1
# ----> 1 from .events import *
#       2 from . import config
#       3 from .components import *
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\frontend\events\__init__.py:1
# ----> 1 from .clipboard import *
#       2 from .event_mixins import *
#       3 from .hash_change import *
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\frontend\events\clipboard.py:2
#       1 from .event_mixins import ClipboardDataMixin
# ----> 2 from ..dom import Event
#       4 __all__ = ['ClipboardEvent']
#       7 class ClipboardEvent(Event, ClipboardDataMixin):
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\frontend\dom.py:439
#     435         except KeyError:
#     436             pass
# --> 439 from . import dispatcher
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\frontend\dispatcher.py:15
#      12 from starlette.endpoints import WebSocketEndpoint
#      13 from starlette.websockets import WebSocket
# ---> 15 from . import config, server
#      16 from .async_utils import later_await
#      18 __all__ = ['react']
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\frontend\server.py:24
#      21 __all__ = ['route', 'run']
#      23 app: Any = Starlette(debug=config.DEBUG)
# ---> 24 app.mount(config.STATIC_ROUTE, StaticFiles(directory=config.STATIC_DIRECTORY), name=config.STATIC_NAME)
#      25 app.add_middleware(GZipMiddleware)
#      26 app.add_middleware(
#      27     CORSMiddleware,
#      28     allow_origins=["*"],
#    (...)     31     allow_headers=["*"],
#      32 )
#
# File c:\Users\Edward\miniconda3\Lib\site-packages\starlette\staticfiles.py:56, in StaticFiles.__init__(self, directory, packages, html, check_dir, follow_symlink)
#      54 self.follow_symlink = follow_symlink
#      55 if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 56     raise RuntimeError(f"Directory '{directory}' does not exist")
#
# RuntimeError: Directory 'static/' does not exist

# %%
pip uninstall fitz
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
